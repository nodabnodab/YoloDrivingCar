# %%
# !pip uninstall opencv-python -y
# !pip install "opencv-python <= 4.5.5"
# Out:
# Found existing installation: opencv-python 4.1.2.30
# Uninstalling opencv-python-4.1.2.30:
#   Successfully uninstalled opencv-python-4.1.2.30
# Collecting opencv-python<=4.5.5
#   Downloading opencv_python-4.5.4.60-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.3 MB)
#      |████████████████████████████████| 60.3 MB 1.3 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python<=4.5.5) (1.21.6)
# Installing collected packages: opencv-python
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed opencv-python-4.5.4.60

# %%
# 내 구글 드라이브에 연동
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# 필요한 패키지와 모듈을 불러옴
import cv2
import numpy as np
import time
import io
import base64
from IPython.display import HTML

# %%
# OpenCV 버전 확인
print(cv2.__version__)
# Out:
# 4.5.4

# %%
# Detection 하기 전에 원본 동영상을 Display
video = io.open('/content/gdrive/MyDrive/Custom_YOLO4/custom_fruit.mp4', 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video width="30%" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4"/>
             </video>'''.format(encoded.decode('ascii')))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
file_name = '/content/gdrive/MyDrive/Custom_YOLO4/custom_fruit.mp4'  # Detection 할 원본 동영상
min_confidence = 0.5  # detection 으로 인정할 최소 확률(신뢰도) 지정
nms_threshold = 0.4   # non-max suppression threshold
output_name = 'fruit_output_video.mp4'  # Detection 된 output 동영상 
elapsed_time = 0       # 총 경과시간 초기화

# %%
def detectAndDisplay(frame):
    start_time = time.time()

    global min_confidence
    global nms_threshold
    classIds, scores, boxes = model.detect(frame, confThreshold=min_confidence, nmsThreshold=nms_threshold)

    font = cv2.FONT_HERSHEY_PLAIN
    for i in range(len(boxes)):
        x, y, w, h = boxes[i]
        label = '{} {:,.2%}'.format(str(classes[classIds[i]]), scores[i])
        print(i, label)
        color = color_lists[classIds[i]]
        cv2.rectangle(frame, (x, y), (x + w, y + h), color, 1)
        cv2.rectangle(frame, (x, y-25), (x + w, y), color, -1)
        cv2.putText(frame, label, (x+2, y - 10), font, 1, (255, 255, 255), 1)

    process_time = time.time() - start_time
    global elapsed_time
    elapsed_time += process_time   # 총 경과시간 누적
    print("=== A frame took {:.3f} seconds".format(process_time))

    # video 를 disk 에 output 하기 위해 writer 를 초기화한다.
    global writer
    if writer is None and output_name is not None:
        fourcc = cv2.VideoWriter_fourcc(*"DIVX")
        writer = cv2.VideoWriter(output_name, fourcc, 20,
                (frame.shape[1], frame.shape[0]), True)
        
    # disk 에 frame 을 write 합니다.
    if writer is not None:
        writer.write(frame)

# %%
# Load YOLO
net = cv2.dnn.readNetFromDarknet("/content/gdrive/MyDrive/Custom_YOLO4/custom/custom-test-yolo4.cfg", "/content/gdrive/MyDrive/Custom_YOLO4/backup/custom-train-yolo4_final.weights")
classes = []   # detection 할 Object(Class) list 배열을 정의
with open("/content/gdrive/MyDrive/Custom_YOLO4/custom/classes.names", "r") as f:
   classes = [line.strip() for line in f.readlines()]   # 3개의 Object(class)를 구분할 수 있는 Object의 이름을 classes 배열에 넣어준다.
color_lists = np.random.uniform(0, 255, size=(len(classes), 3))  # Object 마다 컬러를 하나씩 다르게 지정

model = cv2.dnn_DetectionModel(net)
model.setInputParams(scale=1./255, size=(416, 416), swapRB=True, crop=False)

# 원본 동영상에서 video stream을 읽어온다.
cap = cv2.VideoCapture(file_name)
writer = None
if not cap.isOpened:
    print('--(!)Error opening video capture')
    exit(0)
while True:
    ret, frame = cap.read()
    if frame is None:
        # close the video file pointers
        cap.release()
        # close the writer point
        writer.release()
        print('--(!) No captured frame -- Break!')
        print("elapsed time {:.3f} seconds".format(elapsed_time))
        break
    detectAndDisplay(frame)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 1 Tomato 99.90%
# 2 Tomato 94.09%
# 3 Apple 99.94%
# 4 Apple 99.89%
# === A frame took 1.607 seconds
# 0 Oriental melon 99.58%
# 1 Tomato 99.88%
# 2 Tomato 86.15%
# 3 Tomato 76.17%
# 4 Apple 99.94%
# 5 Apple 99.89%
# === A frame took 1.629 seconds
# 0 Oriental melon 99.43%
# 1 Tomato 99.88%
# 2 Tomato 96.70%
# 3 Tomato 72.37%
# 4 Apple 99.94%
# 5 Apple 99.88%
# === A frame took 1.603 seconds
# 0 Oriental melon 99.61%
# 1 Tomato 99.87%
# 2 Tomato 99.72%
# 3 Tomato 85.24%
# 4 Apple 99.94%
# 5 Apple 99.80%
# === A frame took 1.581 seconds
# 0 Oriental melon 99.54%
# 1 Tomato 99.87%
# 2 Tomato 99.86%
# 3 Tomato 93.18%
# 4 Apple 99.93%
# 5 Apple 99.83%
# === A frame took 1.642 seconds
# 0 Oriental melon 99.47%
# 1 Tomato 99.91%
# 2 Tomato 99.86%
# 3 Tomato 96.61%
# 4 Apple 99.93%
# 5 Apple 99.85%
# === A frame took 1.617 seconds
# 0 Oriental melon 99.55%
# 1 Tomato 99.88%
# 2 Tomato 99.83%
# 3 Apple 99.93%
# 4 Apple 99.86%
# 5 Apple 86.81%
# === A frame took 1.630 seconds
# 0 Oriental melon 99.59%
# 1 Tomato 99.87%
# 2 Tomato 98.37%
# 3 Apple 99.93%
# 4 Apple 99.83%
# 5 Apple 93.82%
# === A frame took 1.585 seconds
# 0 Oriental melon 99.45%
# 1 Tomato 99.86%
# 2 Tomato 96.88%
# 3 Apple 99.93%
# 4 Apple 99.81%
# 5 Apple 93.85%
# === A frame took 1.601 seconds
# 0 Oriental melon 99.54%
# 1 Tomato 99.85%
# 2 Tomato 95.10%
# 3 Apple 99.93%
# 4 Apple 99.82%
# 5 Apple 92.18%
# 6 Apple 50.11%
# === A frame took 1.653 seconds
# 0 Oriental melon 99.34%
# 1 Tomato 99.85%
# 2 Tomato 99.14%
# 3 Apple 99.93%
# 4 Apple 99.80%
# 5 Apple 93.58%
# === A frame took 1.610 seconds
# 0 Oriental melon 99.40%
# 1 Tomato 99.86%
# 2 Tomato 99.59%
# 3 Tomato 56.25%
# 4 Apple 99.93%
# 5 Apple 99.82%
# 6 Apple 93.73%
# === A frame took 1.650 seconds
# 0 Oriental melon 99.44%
# 1 Tomato 99.90%
# 2 Tomato 99.83%
# 3 Tomato 95.44%
# 4 Apple 99.93%
# 5 Apple 99.87%
# === A frame took 1.602 seconds
# 0 Oriental melon 99.68%
# 1 Tomato 99.90%
# 2 Tomato 99.73%
# 3 Tomato 90.17%
# 4 Apple 99.94%
# 5 Apple 99.82%
# === A frame took 1.634 seconds
# 0 Oriental melon 99.75%
# 1 Tomato 99.88%
# 2 Tomato 99.49%
# 3 Tomato 78.76%
# 4 Apple 99.94%
# 5 Apple 99.86%
# === A frame took 1.601 seconds
# 0 Oriental melon 99.68%
# 1 Tomato 99.89%
# 2 Tomato 99.58%
# 3 Tomato 87.49%
# 4 Apple 99.93%
# 5 Apple 99.61%
# === A frame took 1.619 seconds
# 0 Oriental melon 99.61%
# 1 Tomato 99.89%
# 2 Tomato 99.82%
# 3 Apple 99.93%
# 4 Apple 99.12%
# === A frame took 1.637 seconds
# 0 Oriental melon 99.59%
# 1 Tomato 99.90%
# 2 Tomato 99.83%
# 3 Tomato 95.03%
# 4 Apple 99.93%
# 5 Apple 98.35%
# === A frame took 1.595 seconds
# 0 Oriental melon 99.48%
# 1 Tomato 99.88%
# 2 Tomato 99.87%
# 3 Apple 99.93%
# 4 Apple 99.88%
# === A frame took 1.620 seconds
# 0 Oriental melon 99.49%
# 1 Tomato 99.86%
# 2 Tomato 99.84%
# 3 Apple 99.94%
# 4 Apple 99.88%
# === A frame took 1.633 seconds
# 0 Oriental melon 99.53%
# 1 Tomato 99.85%
# 2 Tomato 99.83%
# 3 Apple 99.94%
# 4 Apple 99.89%
# === A frame took 1.615 seconds
# 0 Oriental melon 99.52%
# 1 Tomato 99.85%
# 2 Tomato 99.84%
# 3 Apple 99.94%
# 4 Apple 99.89%
# === A frame took 1.611 seconds
# 0 Oriental melon 99.49%
# 1 Tomato 99.87%
# 2 Tomato 99.82%
# 3 Apple 99.95%
# 4 Apple 99.88%
# === A frame took 1.572 seconds
# 0 Oriental melon 99.55%
# 1 Tomato 99.87%
# 2 Tomato 99.79%
# 3 Apple 99.95%
# 4 Apple 99.85%
# === A frame took 1.590 seconds
# 0 Oriental melon 99.45%
# 1 Tomato 99.86%
# 2 Tomato 99.74%
# 3 Apple 99.95%
# 4 Apple 99.84%
# === A frame took 1.628 seconds
# 0 Oriental melon 99.57%
# 1 Tomato 99.85%
# 2 Tomato 99.78%
# 3 Apple 99.95%
# 4 Apple 99.86%
# === A frame took 1.623 seconds
# 0 Oriental melon 99.51%
# 1 Tomato 99.89%
# 2 Tomato 99.80%
# 3 Apple 99.94%
# 4 Apple 99.88%
# === A frame took 1.643 seconds
# 0 Oriental melon 99.39%
# 1 Tomato 99.93%
# 2 Tomato 99.86%
# 3 Apple 99.94%
# 4 Apple 99.91%
# === A frame took 1.621 seconds
# 0 Oriental melon 99.52%
# 1 Tomato 99.93%
# 2 Tomato 99.88%
# 3 Apple 99.94%
# 4 Apple 99.91%
# === A frame took 1.614 seconds
# 0 Oriental melon 99.48%
# 1 Tomato 99.94%
# 2 Tomato 99.90%
# 3 Apple 99.94%
# 4 Apple 99.91%
# === A frame took 1.612 seconds
# 0 Oriental melon 99.44%
# 1 Tomato 99.94%
# 2 Tomato 99.91%
# 3 Apple 99.94%
# 4 Apple 99.91%
# === A frame took 1.635 seconds
# 0 Oriental melon 99.65%
# 1 Tomato 99.93%
# 2 Tomato 99.90%
# 3 Apple 99.94%
# 4 Apple 99.91%
# === A frame took 1.603 seconds
# 0 Oriental melon 99.58%
# 1 Tomato 99.94%
# 2 Tomato 99.89%
# 3 Apple 99.94%
# 4 Apple 99.91%
# === A frame took 1.648 seconds
# 0 Oriental melon 99.52%
# 1 Tomato 99.93%
# 2 Tomato 99.89%
# 3 Apple 99.94%
# 4 Apple 99.90%
# === A frame took 1.615 seconds
# 0 Oriental melon 99.58%
# 1 Tomato 99.91%
# 2 Tomato 99.86%
# 3 Apple 99.94%
# 4 Apple 99.89%
# === A frame took 1.605 seconds
# 0 Oriental melon 99.46%
# 1 Tomato 99.90%
# 2 Tomato 99.82%
# 3 Apple 99.94%
# 4 Apple 99.88%
# === A frame took 1.631 seconds
# 0 Oriental melon 99.42%
# 1 Tomato 99.90%
# 2 Tomato 99.84%
# 3 Apple 99.94%
# 4 Apple 99.87%
# === A frame took 1.640 seconds
# 0 Oriental melon 99.35%
# 1 Tomato 99.89%
# 2 Tomato 99.85%
# 3 Apple 99.94%
# 4 Apple 99.87%
# === A frame took 1.597 seconds
# 0 Oriental melon 99.36%
# 1 Tomato 99.90%
# 2 Tomato 99.86%
# 3 Apple 99.94%
# 4 Apple 99.88%
# === A frame took 1.620 seconds
# 0 Oriental melon 99.39%
# 1 Tomato 99.92%
# 2 Tomato 99.86%
# 3 Apple 99.94%
# 4 Apple 99.88%
# === A frame took 1.626 seconds
# 0 Oriental melon 99.33%
# 1 Tomato 99.93%
# 2 Tomato 99.85%
# 3 Apple 99.94%
# 4 Apple 99.88%
# === A frame took 1.633 seconds
# 0 Oriental melon 99.50%
# 1 Tomato 99.93%
# 2 Tomato 99.84%
# 3 Apple 99.94%
# 4 Apple 99.90%
# === A frame took 1.618 seconds
# 0 Oriental melon 99.33%
# 1 Tomato 99.93%
# 2 Tomato 99.85%
# 3 Apple 99.94%
# 4 Apple 99.90%
# === A frame took 1.654 seconds
# 0 Oriental melon 99.28%
# 1 Tomato 99.92%
# 2 Tomato 99.87%
# 3 Apple 99.94%
# 4 Apple 99.89%
# === A frame took 1.611 seconds
# 0 Oriental melon 99.37%
# 1 Tomato 99.91%
# 2 Tomato 99.86%
# 3 Apple 99.94%
# 4 Apple 99.89%
# === A frame took 1.594 seconds
# 0 Oriental melon 99.38%
# 1 Tomato 99.92%
# 2 Tomato 99.84%
# 3 Apple 99.94%
# 4 Apple 99.89%
# === A frame took 1.643 seconds
# 0 Oriental melon 99.34%
# 1 Tomato 99.92%
# 2 Tomato 99.86%
# 3 Apple 99.94%
# 4 Apple 99.89%
# === A frame took 1.617 seconds
# 0 Oriental melon 99.32%
# 1 Tomato 99.92%
# 2 Tomato 99.85%
# 3 Apple 99.94%
# 4 Apple 99.89%
# === A frame took 1.604 seconds
# 0 Oriental melon 99.40%
# 1 Tomato 99.92%
# 2 Tomato 99.87%
# 3 Apple 99.94%
# 4 Apple 99.89%
# === A frame took 1.609 seconds
# 0 Oriental melon 99.49%
# 1 Tomato 99.93%
# 2 Tomato 99.84%
# 3 Apple 99.93%
# 4 Apple 99.89%
# === A frame took 1.621 seconds
# 0 Oriental melon 99.35%
# 1 Tomato 99.92%
# 2 Tomato 99.85%
# 3 Apple 99.93%
# 4 Apple 99.88%
# === A frame took 1.606 seconds
# 0 Oriental melon 99.46%
# 1 Tomato 99.91%
# 2 Tomato 99.86%
# 3 Apple 99.94%
# 4 Apple 99.89%
# === A frame took 1.599 seconds
# 0 Oriental melon 99.40%
# 1 Tomato 99.89%
# 2 Tomato 99.83%
# 3 Apple 99.94%
# 4 Apple 99.86%
# === A frame took 1.603 seconds
# 0 Oriental melon 99.33%
# 1 Tomato 99.87%
# 2 Tomato 99.84%
# 3 Apple 99.94%
# 4 Apple 99.84%
# === A frame took 1.632 seconds
# 0 Oriental melon 99.33%
# 1 Tomato 99.85%
# 2 Tomato 99.82%
# 3 Apple 99.94%
# 4 Apple 99.82%
# === A frame took 1.631 seconds
# 0 Oriental melon 99.35%
# 1 Tomato 99.87%
# 2 Tomato 99.77%
# 3 Apple 99.94%
# 4 Apple 99.81%
# === A frame took 1.616 seconds
# 0 Oriental melon 99.44%
# 1 Tomato 99.84%
# 2 Tomato 99.79%
# 3 Apple 99.94%
# 4 Apple 99.84%
# === A frame took 1.587 seconds
# 0 Oriental melon 99.40%
# 1 Tomato 99.90%
# 2 Tomato 99.79%
# 3 Apple 99.94%
# 4 Apple 99.88%
# === A frame took 1.662 seconds
# 0 Oriental melon 99.54%
# 1 Tomato 99.92%
# 2 Tomato 99.82%
# 3 Apple 99.94%
# 4 Apple 99.88%
# === A frame took 1.658 seconds
# 0 Oriental melon 99.45%
# 1 Tomato 99.92%
# 2 Tomato 99.83%
# 3 Apple 99.94%
# 4 Apple 99.89%
# === A frame took 1.616 seconds
# 0 Oriental melon 99.36%
# 1 Tomato 99.92%
# 2 Tomato 99.85%
# 3 Apple 99.94%
# 4 Apple 99.89%
# === A frame took 1.643 seconds
# 0 Oriental melon 99.48%
# 1 Tomato 99.89%
# 2 Tomato 99.84%
# 3 Apple 99.94%
# 4 Apple 99.87%
# === A frame took 1.600 seconds
# 0 Oriental melon 99.45%
# 1 Tomato 99.89%
# 2 Tomato 99.84%
# 3 Apple 99.94%
# 4 Apple 99.86%
# === A frame took 1.623 seconds
# 0 Oriental melon 99.27%
# 1 Tomato 99.88%
# 2 Tomato 99.80%
# 3 Apple 99.94%
# 4 Apple 99.84%
# === A frame took 1.610 seconds
# 0 Oriental melon 99.23%
# 1 Tomato 99.89%
# 2 Tomato 99.81%
# 3 Apple 99.94%
# 4 Apple 99.85%
# === A frame took 1.617 seconds
# 0 Oriental melon 99.39%
# 1 Tomato 99.89%
# 2 Tomato 99.81%
# 3 Apple 99.94%
# 4 Apple 99.85%
# === A frame took 1.598 seconds
# 0 Oriental melon 99.37%
# 1 Tomato 99.88%
# 2 Tomato 99.79%
# 3 Apple 99.94%
# 4 Apple 99.85%
# === A frame took 1.629 seconds
# 0 Oriental melon 99.32%
# 1 Tomato 99.89%
# 2 Tomato 99.80%
# 3 Apple 99.94%
# 4 Apple 99.85%
# === A frame took 1.678 seconds
# 0 Oriental melon 99.52%
# 1 Tomato 99.88%
# 2 Tomato 99.80%
# 3 Apple 99.94%
# 4 Apple 99.84%
# === A frame took 1.620 seconds
# 0 Oriental melon 99.20%
# 1 Tomato 99.87%
# 2 Tomato 99.80%
# 3 Apple 99.94%
# 4 Apple 99.82%
# === A frame took 1.646 seconds
# 0 Oriental melon 99.41%
# 1 Tomato 99.89%
# 2 Tomato 99.75%
# 3 Apple 99.94%
# 4 Apple 99.83%
# === A frame took 1.635 seconds
# 0 Oriental melon 99.45%
# 1 Tomato 99.92%
# 2 Tomato 99.71%
# 3 Apple 99.94%
# 4 Apple 99.81%
# === A frame took 1.623 seconds
# 0 Oriental melon 99.31%
# 1 Tomato 99.91%
# 2 Tomato 99.72%
# 3 Apple 99.94%
# 4 Apple 99.79%
# === A frame took 1.623 seconds
# 0 Oriental melon 99.32%
# 1 Tomato 99.90%
# 2 Tomato 99.76%
# 3 Apple 99.93%
# 4 Apple 99.81%
# === A frame took 1.628 seconds
# 0 Oriental melon 99.44%
# 1 Tomato 99.90%
# 2 Tomato 99.75%
# 3 Apple 99.93%
# 4 Apple 99.81%
# === A frame took 1.627 seconds
# 0 Oriental melon 99.48%
# 1 Tomato 99.91%
# 2 Tomato 99.74%
# 3 Apple 99.93%
# 4 Apple 99.81%
# === A frame took 1.617 seconds
# 0 Oriental melon 99.47%
# 1 Tomato 99.91%
# 2 Tomato 99.75%
# 3 Apple 99.93%
# 4 Apple 99.81%
# === A frame took 1.631 seconds
# 0 Oriental melon 99.56%
# 1 Tomato 99.90%
# 2 Tomato 99.76%
# 3 Apple 99.93%
# 4 Apple 99.80%
# === A frame took 1.618 seconds
# 0 Oriental melon 99.41%
# 1 Tomato 99.93%
# 2 Tomato 99.38%
# 3 Apple 99.93%
# 4 Apple 99.73%
# === A frame took 1.608 seconds
# 0 Oriental melon 99.38%
# 1 Tomato 99.93%
# 2 Tomato 99.48%
# 3 Apple 99.93%
# 4 Apple 99.73%
# === A frame took 1.616 seconds
# 0 Oriental melon 99.35%
# 1 Tomato 99.94%
# 2 Tomato 99.43%
# 3 Apple 99.93%
# 4 Apple 99.74%
# === A frame took 1.607 seconds
# 0 Oriental melon 99.33%
# 1 Tomato 99.94%
# 2 Tomato 99.56%
# 3 Apple 99.94%
# 4 Apple 99.73%
# === A frame took 1.660 seconds
# 0 Oriental melon 99.38%
# 1 Tomato 99.94%
# 2 Tomato 99.57%
# 3 Apple 99.93%
# 4 Apple 99.71%
# === A frame took 1.587 seconds
# 0 Oriental melon 99.31%
# 1 Tomato 99.94%
# 2 Tomato 99.50%
# 3 Apple 99.93%
# 4 Apple 99.71%
# === A frame took 1.662 seconds
# 0 Oriental melon 99.46%
# 1 Tomato 99.94%
# 2 Tomato 99.65%
# 3 Apple 99.93%
# 4 Apple 99.73%
# === A frame took 1.601 seconds
# 0 Oriental melon 99.49%
# 1 Tomato 99.94%
# 2 Tomato 99.68%
# 3 Apple 99.94%
# 4 Apple 99.76%
# === A frame took 1.610 seconds
# 0 Oriental melon 99.44%
# 1 Tomato 99.94%
# 2 Tomato 99.64%
# 3 Apple 99.93%
# 4 Apple 99.76%
# === A frame took 1.624 seconds
# 0 Oriental melon 99.45%
# 1 Tomato 99.94%
# 2 Tomato 99.67%
# 3 Apple 99.93%
# 4 Apple 99.77%
# === A frame took 1.594 seconds
# 0 Oriental melon 99.46%
# 1 Tomato 99.94%
# 2 Tomato 99.67%
# 3 Apple 99.94%
# 4 Apple 99.78%
# === A frame took 1.658 seconds
# 0 Oriental melon 99.49%
# 1 Tomato 99.94%
# 2 Tomato 99.68%
# 3 Apple 99.93%
# 4 Apple 99.77%
# === A frame took 1.636 seconds
# 0 Oriental melon 99.38%
# 1 Tomato 99.94%
# 2 Tomato 99.58%
# 3 Apple 99.93%
# 4 Apple 99.76%
# === A frame took 1.646 seconds
# 0 Oriental melon 99.44%
# 1 Tomato 99.95%
# 2 Tomato 99.59%
# 3 Apple 99.93%
# 4 Apple 99.75%
# === A frame took 1.658 seconds
# 0 Oriental melon 99.28%
# 1 Tomato 99.95%
# 2 Tomato 99.58%
# 3 Apple 99.93%
# 4 Apple 99.75%
# === A frame took 1.625 seconds
# 0 Oriental melon 99.34%
# 1 Tomato 99.94%
# 2 Tomato 99.63%
# 3 Apple 99.93%
# 4 Apple 99.73%
# === A frame took 1.648 seconds
# 0 Oriental melon 99.45%
# 1 Tomato 99.94%
# 2 Tomato 99.62%
# 3 Apple 99.93%
# 4 Apple 99.77%
# === A frame took 1.647 seconds
# 0 Oriental melon 99.49%
# 1 Tomato 99.95%
# 2 Tomato 99.60%
# 3 Apple 99.93%
# 4 Apple 99.77%
# === A frame took 1.648 seconds
# 0 Oriental melon 99.43%
# 1 Tomato 99.95%
# 2 Tomato 99.56%
# 3 Apple 99.93%
# 4 Apple 99.79%
# === A frame took 1.671 seconds
# 0 Oriental melon 99.49%
# 1 Tomato 99.94%
# 2 Tomato 99.52%
# 3 Apple 99.93%
# 4 Apple 99.76%
# === A frame took 1.657 seconds
# 0 Oriental melon 99.50%
# 1 Tomato 99.93%
# 2 Tomato 99.51%
# 3 Apple 99.93%
# 4 Apple 99.70%
# === A frame took 1.648 seconds
# 0 Oriental melon 99.25%
# 1 Tomato 99.94%
# 2 Tomato 99.46%
# 3 Apple 99.93%
# 4 Apple 99.75%
# === A frame took 1.655 seconds
# 0 Oriental melon 99.32%
# 1 Tomato 99.93%
# 2 Tomato 99.43%
# 3 Apple 99.93%
# 4 Apple 99.79%
# === A frame took 1.633 seconds
# 0 Oriental melon 99.41%
# 1 Tomato 99.92%
# 2 Tomato 99.25%
# 3 Apple 99.93%
# 4 Apple 99.81%
# === A frame took 1.622 seconds
# 0 Oriental melon 99.46%
# 1 Tomato 99.93%
# 2 Tomato 99.29%
# 3 Apple 99.93%
# 4 Apple 99.78%
# === A frame took 1.629 seconds
# 0 Oriental melon 99.35%
# 1 Tomato 99.94%
# 2 Tomato 99.40%
# 3 Apple 99.93%
# 4 Apple 99.72%
# === A frame took 1.641 seconds
# 0 Oriental melon 99.34%
# 1 Tomato 99.93%
# 2 Tomato 99.55%
# 3 Apple 99.93%
# 4 Apple 99.74%
# === A frame took 1.627 seconds
# 0 Oriental melon 99.33%
# 1 Tomato 99.93%
# 2 Tomato 99.51%
# 3 Tomato 84.93%
# 4 Apple 99.93%
# 5 Apple 99.76%
# === A frame took 1.606 seconds
# 0 Oriental melon 98.96%
# 1 Tomato 99.93%
# 2 Tomato 99.48%
# 3 Tomato 84.00%
# 4 Apple 99.93%
# 5 Apple 99.79%
# === A frame took 1.639 seconds
# 0 Oriental melon 99.02%
# 1 Tomato 99.91%
# 2 Tomato 99.49%
# 3 Apple 99.93%
# 4 Apple 99.78%
# === A frame took 1.710 seconds
# 0 Oriental melon 99.59%
# 1 Tomato 99.92%
# 2 Tomato 99.54%
# 3 Tomato 81.19%
# 4 Apple 99.81%
# 5 Apple 99.28%
# === A frame took 1.637 seconds
# 0 Oriental melon 99.15%
# 1 Tomato 99.91%
# 2 Tomato 99.53%
# 3 Apple 99.80%
# 4 Apple 99.61%
# === A frame took 1.636 seconds
# 0 Oriental melon 99.54%
# 1 Tomato 99.92%
# 2 Tomato 99.55%
# 3 Apple 99.76%
# 4 Apple 99.76%
# === A frame took 1.631 seconds
# 0 Oriental melon 99.15%
# 1 Tomato 99.90%
# 2 Tomato 99.48%
# 3 Tomato 74.10%
# 4 Apple 99.84%
# === A frame took 1.657 seconds
# 0 Oriental melon 99.61%
# 1 Tomato 99.90%
# 2 Tomato 99.43%
# 3 Tomato 72.24%
# 4 Apple 99.60%
# === A frame took 1.651 seconds
# 0 Oriental melon 99.48%
# 1 Tomato 99.89%
# 2 Tomato 99.36%
# 3 Apple 99.82%
# === A frame took 1.625 seconds
# 0 Tomato 99.90%
# 1 Tomato 99.61%
# 2 Tomato 93.33%
# 3 Apple 99.84%
# === A frame took 1.649 seconds
# 0 Oriental melon 94.45%
# 1 Tomato 99.90%
# 2 Tomato 99.58%
# 3 Apple 99.86%
# === A frame took 1.630 seconds
# 0 Oriental melon 87.67%
# 1 Tomato 99.89%
# 2 Tomato 99.39%
# 3 Tomato 56.10%
# 4 Apple 99.85%
# === A frame took 1.631 seconds
# 0 Tomato 99.92%
# 1 Tomato 99.59%
# 2 Tomato 94.28%
# 3 Tomato 58.57%
# 4 Apple 99.85%
# === A frame took 1.647 seconds
# 0 Oriental melon 92.96%
# 1 Tomato 99.90%
# 2 Tomato 99.44%
# 3 Tomato 57.63%
# 4 Apple 99.86%
# === A frame took 1.656 seconds
# 0 Oriental melon 73.06%
# 1 Tomato 99.90%
# 2 Tomato 98.65%
# 3 Tomato 85.82%
# 4 Apple 99.85%
# === A frame took 1.649 seconds
# 0 Oriental melon 92.88%
# 1 Tomato 99.90%
# 2 Tomato 98.43%
# 3 Apple 99.81%
# === A frame took 1.689 seconds
# 0 Oriental melon 97.18%
# 1 Tomato 99.86%
# 2 Tomato 98.92%
# 3 Apple 99.73%
# === A frame took 1.646 seconds
# 0 Oriental melon 97.52%
# 1 Tomato 99.85%
# 2 Tomato 99.65%
# 3 Apple 99.74%
# === A frame took 1.640 seconds
# 0 Oriental melon 95.61%
# 1 Tomato 99.84%
# 2 Tomato 99.72%
# 3 Apple 99.73%
# === A frame took 1.611 seconds
# 0 Oriental melon 88.64%
# 1 Tomato 99.85%
# 2 Tomato 99.72%
# 3 Apple 99.68%
# === A frame took 1.666 seconds
# 0 Oriental melon 92.10%
# 1 Tomato 99.87%
# 2 Tomato 99.60%
# 3 Apple 99.69%
# === A frame took 1.681 seconds
# 0 Oriental melon 89.96%
# 1 Tomato 99.87%
# 2 Tomato 99.71%
# 3 Apple 99.57%
# === A frame took 1.666 seconds
# 0 Oriental melon 62.20%
# 1 Tomato 99.88%
# 2 Tomato 99.67%
# 3 Tomato 73.69%
# 4 Apple 99.59%
# === A frame took 1.659 seconds
# 0 Oriental melon 92.83%
# 1 Tomato 99.89%
# 2 Tomato 99.68%
# 3 Apple 99.71%
# === A frame took 1.636 seconds
# 0 Oriental melon 94.86%
# 1 Tomato 99.90%
# 2 Tomato 99.73%
# 3 Apple 99.74%
# === A frame took 1.653 seconds
# 0 Oriental melon 93.35%
# 1 Tomato 99.88%
# 2 Tomato 99.82%
# 3 Apple 99.70%
# === A frame took 1.658 seconds
# 0 Tomato 99.89%
# 1 Tomato 99.86%
# 2 Tomato 73.29%
# 3 Apple 99.72%
# === A frame took 1.636 seconds
# 0 Oriental melon 72.32%
# 1 Tomato 99.90%
# 2 Tomato 99.85%
# 3 Apple 99.75%
# === A frame took 1.649 seconds
# 0 Tomato 99.91%
# 1 Tomato 99.85%
# 2 Tomato 97.37%
# 3 Apple 99.74%
# === A frame took 1.670 seconds
# 0 Tomato 99.91%
# 1 Tomato 99.85%
# 2 Tomato 98.37%
# 3 Apple 99.77%
# === A frame took 1.654 seconds
# 0 Oriental melon 91.45%
# 1 Tomato 99.90%
# 2 Tomato 99.82%
# 3 Apple 99.74%
# === A frame took 1.636 seconds
# 0 Oriental melon 95.53%
# 1 Tomato 99.90%
# 2 Tomato 99.78%
# 3 Apple 99.74%
# === A frame took 1.660 seconds
# 0 Oriental melon 94.39%
# 1 Tomato 99.90%
# 2 Tomato 99.74%
# 3 Apple 99.73%
# === A frame took 1.635 seconds
# 0 Oriental melon 95.15%
# 1 Tomato 99.91%
# 2 Tomato 99.83%
# 3 Apple 99.79%
# === A frame took 1.650 seconds
# 0 Oriental melon 65.60%
# 1 Tomato 99.91%
# 2 Tomato 99.72%
# 3 Apple 99.80%
# === A frame took 1.633 seconds
# 0 Tomato 99.91%
# 1 Tomato 99.77%
# 2 Apple 99.78%
# === A frame took 1.616 seconds
# 0 Oriental melon 88.88%
# 1 Tomato 99.91%
# 2 Tomato 99.76%
# 3 Apple 99.77%
# === A frame took 1.624 seconds
# 0 Tomato 99.92%
# 1 Tomato 99.84%
# 2 Tomato 51.87%
# 3 Apple 99.82%
# === A frame took 1.610 seconds
# 0 Tomato 99.91%
# 1 Tomato 99.82%
# 2 Apple 99.82%
# === A frame took 1.669 seconds
# 0 Oriental melon 56.38%
# 1 Tomato 99.92%
# 2 Tomato 99.81%
# 3 Apple 99.82%
# === A frame took 1.633 seconds
# 0 Tomato 99.92%
# 1 Tomato 99.80%
# 2 Tomato 79.91%
# 3 Apple 99.83%
# === A frame took 1.627 seconds
# 0 Tomato 99.92%
# 1 Tomato 99.74%
# 2 Apple 99.83%
# === A frame took 1.623 seconds
# 0 Tomato 99.92%
# 1 Tomato 99.77%
# 2 Apple 99.82%
# === A frame took 1.622 seconds
# 0 Tomato 99.91%
# 1 Tomato 99.72%
# 2 Tomato 61.66%
# 3 Apple 99.79%
# === A frame took 1.636 seconds
# 0 Tomato 99.91%
# 1 Tomato 99.81%
# 2 Apple 99.76%
# 3 Apple 77.94%
# === A frame took 1.617 seconds
# 0 Tomato 99.92%
# 1 Tomato 99.76%
# 2 Apple 99.57%
# 3 Apple 78.19%
# === A frame took 1.637 seconds
# 0 Tomato 99.92%
# 1 Tomato 99.52%
# 2 Apple 99.57%
# 3 Apple 58.21%
# === A frame took 1.613 seconds
# 0 Tomato 99.93%
# 1 Tomato 99.33%
# 2 Apple 99.55%
# 3 Apple 61.07%
# === A frame took 1.613 seconds
# 0 Tomato 99.93%
# 1 Tomato 99.21%
# 2 Apple 99.37%
# === A frame took 1.622 seconds
# 0 Oriental melon 89.45%
# 1 Tomato 99.92%
# 2 Tomato 99.85%
# 3 Apple 98.80%
# === A frame took 1.609 seconds
# 0 Tomato 99.90%
# 1 Tomato 99.84%
# 2 Tomato 74.70%
# 3 Apple 98.85%
# === A frame took 1.596 seconds
# 0 Oriental melon 97.21%
# 1 Oriental melon 78.74%
# 2 Tomato 99.91%
# 3 Tomato 99.86%
# 4 Apple 74.35%
# === A frame took 1.601 seconds
# 0 Oriental melon 70.01%
# 1 Oriental melon 56.74%
# 2 Tomato 99.91%
# 3 Tomato 99.79%
# 4 Tomato 52.58%
# === A frame took 1.610 seconds
# 0 Oriental melon 71.42%
# 1 Tomato 99.94%
# 2 Tomato 99.80%
# 3 Tomato 51.77%
# === A frame took 1.639 seconds
# 0 Oriental melon 63.76%
# 1 Tomato 99.92%
# 2 Tomato 99.79%
# 3 Tomato 83.34%
# === A frame took 1.614 seconds
# 0 Oriental melon 89.61%
# 1 Tomato 99.87%
# 2 Tomato 99.77%
# === A frame took 1.624 seconds
# 0 Oriental melon 96.98%
# 1 Oriental melon 86.12%
# 2 Tomato 99.87%
# 3 Tomato 99.59%
# === A frame took 1.629 seconds
# 0 Oriental melon 97.14%
# 1 Tomato 99.00%
# 2 Tomato 96.28%
# === A frame took 1.623 seconds
# 0 Oriental melon 68.07%
# 1 Tomato 98.20%
# 2 Tomato 96.77%
# === A frame took 1.650 seconds
# 0 Tomato 98.31%
# 1 Tomato 97.65%
# 2 Tomato 80.50%
# === A frame took 1.606 seconds
# 0 Tomato 99.09%
# 1 Tomato 98.17%
# 2 Tomato 94.64%
# === A frame took 1.623 seconds
# 0 Oriental melon 99.34%
# 1 Tomato 99.52%
# 2 Tomato 99.03%
# 3 Tomato 60.86%
# === A frame took 1.626 seconds
# 0 Oriental melon 98.97%
# 1 Tomato 99.81%
# 2 Tomato 99.40%
# 3 Tomato 76.99%
# 4 Apple 98.78%
# === A frame took 1.630 seconds
# 0 Oriental melon 99.67%
# 1 Oriental melon 99.45%
# 2 Tomato 99.86%
# 3 Tomato 99.40%
# === A frame took 1.615 seconds
# 0 Oriental melon 99.78%
# 1 Oriental melon 99.21%
# 2 Tomato 99.94%
# 3 Tomato 99.65%
# 4 Apple 99.48%
# === A frame took 1.637 seconds
# 0 Oriental melon 99.40%
# 1 Oriental melon 97.06%
# 2 Tomato 99.93%
# 3 Tomato 99.44%
# 4 Apple 99.93%
# 5 Apple 99.82%
# === A frame took 1.650 seconds
# 0 Oriental melon 99.65%
# 1 Oriental melon 98.97%
# 2 Tomato 99.92%
# 3 Tomato 99.49%
# 4 Apple 99.94%
# 5 Apple 99.83%
# === A frame took 1.627 seconds
# 0 Oriental melon 99.36%
# 1 Oriental melon 98.61%
# 2 Tomato 99.93%
# 3 Tomato 99.47%
# 4 Apple 99.93%
# 5 Apple 99.83%
# === A frame took 1.649 seconds
# 0 Oriental melon 99.42%
# 1 Oriental melon 99.37%
# 2 Tomato 99.92%
# 3 Tomato 99.52%
# 4 Apple 99.93%
# 5 Apple 99.86%
# === A frame took 1.635 seconds
# 0 Oriental melon 99.45%
# 1 Oriental melon 99.07%
# 2 Tomato 99.89%
# 3 Tomato 99.46%
# 4 Apple 99.93%
# 5 Apple 99.85%
# === A frame took 1.642 seconds
# 0 Oriental melon 99.59%
# 1 Oriental melon 99.11%
# 2 Tomato 99.91%
# 3 Tomato 99.60%
# 4 Apple 99.93%
# 5 Apple 99.84%
# === A frame took 1.647 seconds
# 0 Oriental melon 99.57%
# 1 Oriental melon 99.12%
# 2 Tomato 99.92%
# 3 Tomato 99.69%
# 4 Apple 99.93%
# 5 Apple 99.84%
# === A frame took 1.626 seconds
# 0 Oriental melon 99.60%
# 1 Oriental melon 98.99%
# 2 Tomato 99.92%
# 3 Tomato 99.70%
# 4 Apple 99.93%
# 5 Apple 99.84%
# === A frame took 1.620 seconds
# 0 Oriental melon 99.63%
# 1 Oriental melon 98.91%
# 2 Tomato 99.91%
# 3 Tomato 99.67%
# 4 Apple 99.93%
# 5 Apple 99.87%
# === A frame took 1.617 seconds
# 0 Oriental melon 99.69%
# 1 Oriental melon 99.07%
# 2 Tomato 99.92%
# 3 Tomato 99.70%
# 4 Apple 99.93%
# 5 Apple 99.89%
# === A frame took 1.613 seconds
# 0 Oriental melon 99.53%
# 1 Oriental melon 99.27%
# 2 Tomato 99.91%
# 3 Tomato 99.77%
# 4 Apple 99.93%
# 5 Apple 99.87%
# === A frame took 1.595 seconds
# 0 Oriental melon 99.60%
# 1 Oriental melon 99.51%
# 2 Tomato 99.91%
# 3 Tomato 99.71%
# 4 Apple 99.93%
# 5 Apple 99.88%
# === A frame took 1.620 seconds
# 0 Oriental melon 99.51%
# 1 Oriental melon 99.47%
# 2 Tomato 99.91%
# 3 Tomato 99.75%
# 4 Apple 99.93%
# 5 Apple 99.86%
# === A frame took 1.614 seconds
# 0 Oriental melon 99.59%
# 1 Oriental melon 98.83%
# 2 Tomato 99.92%
# 3 Tomato 99.73%
# 4 Apple 99.93%
# 5 Apple 99.86%
# === A frame took 1.596 seconds
# 0 Oriental melon 99.52%
# 1 Oriental melon 99.00%
# 2 Tomato 99.92%
# 3 Tomato 99.73%
# 4 Apple 99.92%
# 5 Apple 99.87%
# === A frame took 1.623 seconds
# 0 Oriental melon 99.58%
# 1 Oriental melon 99.32%
# 2 Tomato 99.92%
# 3 Tomato 99.73%
# 4 Apple 99.93%
# 5 Apple 99.86%
# === A frame took 1.595 seconds
# 0 Oriental melon 99.67%
# 1 Oriental melon 99.41%
# 2 Tomato 99.92%
# 3 Tomato 99.78%
# 4 Apple 99.93%
# 5 Apple 99.86%
# === A frame took 1.612 seconds
# 0 Oriental melon 99.66%
# 1 Oriental melon 98.96%
# 2 Tomato 99.92%
# 3 Tomato 99.78%
# 4 Apple 99.93%
# 5 Apple 99.88%
# === A frame took 1.624 seconds
# 0 Oriental melon 99.66%
# 1 Oriental melon 99.11%
# 2 Tomato 99.92%
# 3 Tomato 99.77%
# 4 Apple 99.93%
# 5 Apple 99.87%
# === A frame took 1.646 seconds
# 0 Oriental melon 99.66%
# 1 Oriental melon 98.85%
# 2 Tomato 99.92%
# 3 Tomato 99.77%
# 4 Apple 99.93%
# 5 Apple 99.87%
# === A frame took 1.634 seconds
# 0 Oriental melon 99.63%
# 1 Oriental melon 97.98%
# 2 Tomato 99.92%
# 3 Tomato 99.77%
# 4 Apple 99.93%
# 5 Apple 99.89%
# === A frame took 1.631 seconds
# 0 Oriental melon 99.70%
# 1 Oriental melon 99.09%
# 2 Tomato 99.92%
# 3 Tomato 99.75%
# 4 Apple 99.93%
# 5 Apple 99.88%
# === A frame took 1.640 seconds
# 0 Oriental melon 99.73%
# 1 Oriental melon 99.25%
# 2 Tomato 99.91%
# 3 Tomato 99.75%
# 4 Apple 99.93%
# 5 Apple 99.87%
# === A frame took 1.632 seconds
# 0 Oriental melon 99.67%
# 1 Oriental melon 98.77%
# 2 Tomato 99.90%
# 3 Tomato 99.76%
# 4 Apple 99.93%
# 5 Apple 99.86%
# === A frame took 1.636 seconds
# 0 Oriental melon 99.76%
# 1 Oriental melon 99.29%
# 2 Tomato 99.91%
# 3 Tomato 99.77%
# 4 Apple 99.93%
# 5 Apple 99.87%
# === A frame took 1.629 seconds
# 0 Oriental melon 99.70%
# 1 Oriental melon 99.30%
# 2 Tomato 99.91%
# 3 Tomato 99.72%
# 4 Apple 99.92%
# 5 Apple 99.87%
# === A frame took 1.620 seconds
# 0 Oriental melon 99.62%
# 1 Oriental melon 98.83%
# 2 Tomato 99.90%
# 3 Tomato 99.75%
# 4 Apple 99.92%
# 5 Apple 99.87%
# === A frame took 1.607 seconds
# 0 Oriental melon 99.69%
# 1 Oriental melon 99.11%
# 2 Tomato 99.90%
# 3 Tomato 99.77%
# 4 Apple 99.93%
# 5 Apple 99.85%
# === A frame took 1.619 seconds
# 0 Oriental melon 99.68%
# 1 Oriental melon 98.73%
# 2 Tomato 99.91%
# 3 Tomato 99.77%
# 4 Apple 99.93%
# 5 Apple 99.85%
# === A frame took 1.633 seconds
# 0 Oriental melon 99.70%
# 1 Oriental melon 99.17%
# 2 Tomato 99.91%
# 3 Tomato 99.80%
# 4 Apple 99.93%
# 5 Apple 99.85%
# === A frame took 1.597 seconds
# 0 Oriental melon 99.71%
# 1 Oriental melon 98.83%
# 2 Tomato 99.92%
# 3 Tomato 99.81%
# 4 Apple 99.92%
# 5 Apple 99.85%
# === A frame took 1.633 seconds
# 0 Oriental melon 99.72%
# 1 Oriental melon 99.16%
# 2 Tomato 99.94%
# 3 Tomato 99.83%
# 4 Apple 99.92%
# 5 Apple 99.89%
# === A frame took 1.653 seconds
# 0 Oriental melon 99.69%
# 1 Oriental melon 99.30%
# 2 Tomato 99.95%
# 3 Tomato 99.88%
# 4 Apple 99.92%
# 5 Apple 99.90%
# === A frame took 1.640 seconds
# 0 Oriental melon 99.58%
# 1 Oriental melon 98.13%
# 2 Tomato 99.95%
# 3 Tomato 99.88%
# 4 Apple 99.92%
# 5 Apple 99.91%
# === A frame took 1.620 seconds
# 0 Oriental melon 99.69%
# 1 Oriental melon 99.18%
# 2 Tomato 99.95%
# 3 Tomato 99.88%
# 4 Apple 99.92%
# 5 Apple 99.91%
# === A frame took 1.630 seconds
# 0 Oriental melon 99.53%
# 1 Oriental melon 97.48%
# 2 Tomato 99.95%
# 3 Tomato 99.87%
# 4 Apple 99.92%
# 5 Apple 99.89%
# === A frame took 1.634 seconds
# 0 Oriental melon 99.33%
# 1 Oriental melon 96.25%
# 2 Tomato 99.94%
# 3 Tomato 99.80%
# 4 Apple 99.92%
# 5 Apple 99.88%
# === A frame took 1.615 seconds
# 0 Oriental melon 99.48%
# 1 Oriental melon 98.37%
# 2 Tomato 99.93%
# 3 Tomato 99.82%
# 4 Apple 99.92%
# 5 Apple 99.90%
# === A frame took 1.619 seconds
# 0 Oriental melon 99.56%
# 1 Oriental melon 99.02%
# 2 Tomato 99.94%
# 3 Tomato 99.84%
# 4 Apple 99.92%
# 5 Apple 99.89%
# === A frame took 1.590 seconds
# 0 Oriental melon 99.66%
# 1 Oriental melon 98.99%
# 2 Tomato 99.95%
# 3 Tomato 99.86%
# 4 Apple 99.92%
# 5 Apple 99.89%
# === A frame took 1.631 seconds
# 0 Oriental melon 99.51%
# 1 Oriental melon 98.76%
# 2 Tomato 99.95%
# 3 Tomato 99.87%
# 4 Apple 99.92%
# 5 Apple 99.89%
# === A frame took 1.595 seconds
# 0 Oriental melon 99.55%
# 1 Oriental melon 99.38%
# 2 Tomato 99.95%
# 3 Tomato 99.88%
# 4 Apple 99.92%
# 5 Apple 99.90%
# === A frame took 1.615 seconds
# 0 Oriental melon 99.65%
# 1 Oriental melon 99.01%
# 2 Tomato 99.96%
# 3 Tomato 99.88%
# 4 Apple 99.92%
# 5 Apple 99.89%
# === A frame took 1.583 seconds
# 0 Oriental melon 99.62%
# 1 Oriental melon 99.26%
# 2 Tomato 99.96%
# 3 Tomato 99.88%
# 4 Tomato 94.85%
# 5 Apple 99.92%
# 6 Apple 99.89%
# === A frame took 1.657 seconds
# 0 Oriental melon 99.63%
# 1 Oriental melon 99.47%
# 2 Tomato 99.96%
# 3 Tomato 99.86%
# 4 Tomato 92.28%
# 5 Apple 99.92%
# 6 Apple 99.90%
# === A frame took 1.607 seconds
# 0 Oriental melon 99.63%
# 1 Oriental melon 99.32%
# 2 Tomato 99.96%
# 3 Tomato 99.86%
# 4 Tomato 96.64%
# 5 Apple 99.92%
# 6 Apple 99.90%
# === A frame took 1.603 seconds
# 0 Oriental melon 99.50%
# 1 Oriental melon 99.45%
# 2 Tomato 99.96%
# 3 Tomato 99.87%
# 4 Tomato 98.02%
# 5 Apple 99.92%
# 6 Apple 99.90%
# === A frame took 1.619 seconds
# 0 Oriental melon 99.36%
# 1 Oriental melon 99.14%
# 2 Tomato 99.95%
# 3 Tomato 99.87%
# 4 Apple 99.92%
# 5 Apple 99.89%
# 6 Apple 87.18%
# === A frame took 1.597 seconds
# 0 Oriental melon 99.52%
# 1 Oriental melon 99.47%
# 2 Tomato 99.96%
# 3 Tomato 99.86%
# 4 Tomato 99.14%
# 5 Apple 99.92%
# 6 Apple 99.91%
# === A frame took 1.619 seconds
# 0 Oriental melon 99.51%
# 1 Oriental melon 99.17%
# 2 Tomato 99.96%
# 3 Tomato 99.87%
# 4 Tomato 95.01%
# 5 Apple 99.92%
# 6 Apple 99.92%
# === A frame took 1.611 seconds
# 0 Oriental melon 99.35%
# 1 Oriental melon 99.22%
# 2 Tomato 99.96%
# 3 Tomato 99.88%
# 4 Tomato 98.56%
# 5 Apple 99.92%
# 6 Apple 99.92%
# === A frame took 1.643 seconds
# 0 Oriental melon 99.52%
# 1 Oriental melon 99.36%
# 2 Tomato 99.96%
# 3 Tomato 99.89%
# 4 Tomato 95.49%
# 5 Apple 99.92%
# 6 Apple 99.91%
# === A frame took 1.650 seconds
# 0 Oriental melon 99.26%
# 1 Oriental melon 99.24%
# 2 Tomato 99.97%
# 3 Tomato 99.89%
# 4 Apple 99.92%
# 5 Apple 99.91%
# 6 Apple 73.64%
# === A frame took 1.605 seconds
# 0 Oriental melon 99.30%
# 1 Oriental melon 98.88%
# 2 Tomato 99.96%
# 3 Tomato 99.89%
# 4 Tomato 66.21%
# 5 Apple 99.92%
# 6 Apple 99.92%
# === A frame took 1.651 seconds
# 0 Oriental melon 99.34%
# 1 Oriental melon 98.73%
# 2 Tomato 99.96%
# 3 Tomato 99.90%
# 4 Apple 99.91%
# 5 Apple 99.91%
# 6 Apple 89.45%
# === A frame took 1.613 seconds
# 0 Oriental melon 99.41%
# 1 Oriental melon 98.66%
# 2 Tomato 99.96%
# 3 Tomato 99.90%
# 4 Apple 99.92%
# 5 Apple 99.91%
# 6 Apple 92.38%
# === A frame took 1.654 seconds
# 0 Oriental melon 99.08%
# 1 Oriental melon 97.73%
# 2 Tomato 99.97%
# 3 Tomato 99.91%
# 4 Apple 99.92%
# 5 Apple 99.91%
# 6 Apple 63.60%
# === A frame took 1.627 seconds
# 0 Oriental melon 98.59%
# 1 Oriental melon 97.44%
# 2 Tomato 99.97%
# 3 Tomato 99.90%
# 4 Apple 99.91%
# 5 Apple 99.91%
# 6 Apple 67.10%
# === A frame took 1.598 seconds
# 0 Oriental melon 98.84%
# 1 Oriental melon 98.64%
# 2 Tomato 99.97%
# 3 Tomato 99.90%
# 4 Apple 99.92%
# 5 Apple 99.91%
# 6 Apple 95.80%
# === A frame took 1.643 seconds
# 0 Oriental melon 99.36%
# 1 Oriental melon 98.71%
# 2 Tomato 99.96%
# 3 Tomato 99.90%
# 4 Apple 99.92%
# 5 Apple 99.91%
# 6 Apple 96.77%
# === A frame took 1.636 seconds
# 0 Oriental melon 99.63%
# 1 Oriental melon 98.73%
# 2 Tomato 99.96%
# 3 Tomato 99.90%
# 4 Tomato 82.87%
# 5 Apple 99.92%
# 6 Apple 99.91%
# === A frame took 1.598 seconds
# 0 Oriental melon 99.55%
# 1 Oriental melon 98.42%
# 2 Tomato 99.96%
# 3 Tomato 99.89%
# 4 Apple 99.92%
# 5 Apple 99.91%
# 6 Apple 86.30%
# === A frame took 1.614 seconds
# 0 Oriental melon 99.35%
# 1 Oriental melon 98.26%
# 2 Tomato 99.96%
# 3 Tomato 99.87%
# 4 Apple 99.92%
# 5 Apple 99.91%
# 6 Apple 97.83%
# === A frame took 1.601 seconds
# 0 Oriental melon 99.58%
# 1 Oriental melon 97.60%
# 2 Tomato 99.96%
# 3 Tomato 99.88%
# 4 Apple 99.91%
# 5 Apple 99.91%
# 6 Apple 94.69%
# === A frame took 1.572 seconds
# 0 Oriental melon 99.49%
# 1 Oriental melon 97.91%
# 2 Tomato 99.96%
# 3 Tomato 99.89%
# 4 Apple 99.91%
# 5 Apple 99.90%
# 6 Apple 90.79%
# === A frame took 1.599 seconds
# 0 Oriental melon 99.21%
# 1 Oriental melon 98.22%
# 2 Tomato 99.96%
# 3 Tomato 99.88%
# 4 Apple 99.91%
# 5 Apple 99.91%
# 6 Apple 62.60%
# === A frame took 1.619 seconds
# 0 Oriental melon 99.05%
# 1 Oriental melon 97.62%
# 2 Tomato 99.96%
# 3 Tomato 99.89%
# 4 Apple 99.92%
# 5 Apple 99.91%
# 6 Apple 70.26%
# === A frame took 1.603 seconds
# 0 Oriental melon 98.46%
# 1 Oriental melon 97.46%
# 2 Tomato 99.96%
# 3 Tomato 99.89%
# 4 Apple 99.92%
# 5 Apple 99.91%
# 6 Apple 71.87%
# === A frame took 1.650 seconds
# 0 Oriental melon 97.87%
# 1 Oriental melon 97.42%
# 2 Oriental melon 91.08%
# 3 Tomato 99.96%
# 4 Tomato 99.88%
# 5 Apple 99.91%
# 6 Apple 99.91%
# === A frame took 1.630 seconds
# 0 Oriental melon 98.58%
# 1 Oriental melon 97.38%
# 2 Oriental melon 53.09%
# 3 Tomato 99.96%
# 4 Tomato 99.88%
# 5 Apple 99.90%
# 6 Apple 99.90%
# === A frame took 1.600 seconds
# 0 Oriental melon 98.22%
# 1 Oriental melon 98.08%
# 2 Oriental melon 65.86%
# 3 Tomato 99.96%
# 4 Tomato 99.88%
# 5 Apple 99.91%
# 6 Apple 99.90%
# === A frame took 1.647 seconds
# 0 Oriental melon 97.23%
# 1 Oriental melon 96.70%
# 2 Oriental melon 73.46%
# 3 Tomato 99.96%
# 4 Tomato 99.87%
# 5 Apple 99.91%
# 6 Apple 99.90%
# === A frame took 1.632 seconds
# 0 Oriental melon 97.61%
# 1 Oriental melon 96.61%
# 2 Oriental melon 95.25%
# 3 Tomato 99.96%
# 4 Tomato 99.87%
# 5 Apple 99.90%
# 6 Apple 99.89%
# === A frame took 1.617 seconds
# 0 Oriental melon 98.14%
# 1 Oriental melon 95.38%
# 2 Tomato 99.96%
# 3 Tomato 99.88%
# 4 Apple 99.90%
# 5 Apple 99.90%
# 6 Apple 76.48%
# === A frame took 1.597 seconds
# 0 Oriental melon 97.55%
# 1 Oriental melon 92.63%
# 2 Oriental melon 61.33%
# 3 Tomato 99.96%
# 4 Tomato 99.86%
# 5 Apple 99.90%
# 6 Apple 99.89%
# === A frame took 1.615 seconds
# 0 Oriental melon 97.16%
# 1 Oriental melon 89.70%
# 2 Tomato 99.96%
# 3 Tomato 99.87%
# 4 Apple 99.91%
# 5 Apple 99.90%
# 6 Apple 66.11%
# === A frame took 1.637 seconds
# 0 Oriental melon 96.90%
# 1 Oriental melon 96.05%
# 2 Oriental melon 87.72%
# 3 Tomato 99.96%
# 4 Tomato 99.85%
# 5 Apple 99.91%
# 6 Apple 99.89%
# === A frame took 1.605 seconds
# 0 Oriental melon 97.38%
# 1 Oriental melon 88.66%
# 2 Oriental melon 84.21%
# 3 Tomato 99.96%
# 4 Tomato 99.87%
# 5 Apple 99.90%
# 6 Apple 99.88%
# === A frame took 1.636 seconds
# 0 Oriental melon 96.41%
# 1 Oriental melon 75.14%
# 2 Oriental melon 61.65%
# 3 Tomato 99.96%
# 4 Tomato 99.88%
# 5 Apple 99.90%
# 6 Apple 99.88%
# 7 Apple 50.87%
# === A frame took 1.609 seconds
# 0 Oriental melon 96.36%
# 1 Oriental melon 83.84%
# 2 Oriental melon 80.56%
# 3 Tomato 99.96%
# 4 Tomato 99.86%
# 5 Apple 99.90%
# 6 Apple 99.90%
# 7 Apple 86.78%
# === A frame took 1.623 seconds
# 0 Oriental melon 97.56%
# 1 Oriental melon 90.15%
# 2 Oriental melon 84.34%
# 3 Tomato 99.96%
# 4 Tomato 99.88%
# 5 Apple 99.90%
# 6 Apple 99.89%
# === A frame took 1.625 seconds
# 0 Oriental melon 98.18%
# 1 Oriental melon 90.58%
# 2 Oriental melon 74.08%
# 3 Tomato 99.96%
# 4 Tomato 99.87%
# 5 Apple 99.90%
# 6 Apple 99.90%
# === A frame took 1.606 seconds
# 0 Oriental melon 97.88%
# 1 Oriental melon 91.40%
# 2 Oriental melon 90.36%
# 3 Tomato 99.96%
# 4 Tomato 99.88%
# 5 Apple 99.91%
# 6 Apple 99.90%
# === A frame took 1.647 seconds
# 0 Oriental melon 97.90%
# 1 Oriental melon 93.06%
# 2 Oriental melon 88.70%
# 3 Tomato 99.96%
# 4 Tomato 99.88%
# 5 Apple 99.90%
# 6 Apple 99.89%
# === A frame took 1.609 seconds
# 0 Oriental melon 95.51%
# 1 Oriental melon 87.82%
# 2 Oriental melon 84.02%
# 3 Tomato 99.96%
# 4 Tomato 99.86%
# 5 Apple 99.90%
# 6 Apple 99.90%
# === A frame took 1.614 seconds
# 0 Oriental melon 97.63%
# 1 Oriental melon 88.95%
# 2 Oriental melon 70.97%
# 3 Tomato 99.96%
# 4 Tomato 99.86%
# 5 Apple 99.91%
# 6 Apple 99.91%
# === A frame took 1.637 seconds
# 0 Oriental melon 97.30%
# 1 Oriental melon 87.00%
# 2 Oriental melon 83.47%
# 3 Tomato 99.96%
# 4 Tomato 99.87%
# 5 Apple 99.91%
# 6 Apple 99.90%
# === A frame took 1.624 seconds
# 0 Oriental melon 96.78%
# 1 Oriental melon 74.17%
# 2 Tomato 99.96%
# 3 Tomato 99.87%
# 4 Tomato 54.62%
# 5 Apple 99.90%
# 6 Apple 99.90%
# 7 Apple 52.45%
# === A frame took 1.622 seconds
# 0 Oriental melon 94.26%
# 1 Oriental melon 66.74%
# 2 Tomato 99.97%
# 3 Tomato 99.87%
# 4 Tomato 98.02%
# 5 Tomato 76.20%
# 6 Apple 99.90%
# 7 Apple 99.90%
# 8 Apple 54.39%
# === A frame took 1.621 seconds
# 0 Oriental melon 95.75%
# 1 Oriental melon 79.84%
# 2 Tomato 99.96%
# 3 Tomato 99.87%
# 4 Tomato 52.01%
# 5 Apple 99.91%
# 6 Apple 99.90%
# 7 Apple 97.60%
# 8 Apple 88.97%
# === A frame took 1.610 seconds
# 0 Oriental melon 88.65%
# 1 Oriental melon 63.01%
# 2 Tomato 99.97%
# 3 Tomato 99.87%
# 4 Tomato 76.65%
# 5 Apple 99.91%
# 6 Apple 99.90%
# 7 Apple 98.71%
# 8 Apple 87.43%
# === A frame took 1.654 seconds
# 0 Oriental melon 94.27%
# 1 Oriental melon 88.10%
# 2 Tomato 99.97%
# 3 Tomato 99.89%
# 4 Tomato 55.64%
# 5 Apple 99.91%
# 6 Apple 99.91%
# 7 Apple 99.88%
# 8 Apple 86.24%
# === A frame took 1.601 seconds
# 0 Oriental melon 96.69%
# 1 Oriental melon 87.19%
# 2 Tomato 99.97%
# 3 Tomato 99.89%
# 4 Apple 99.92%
# 5 Apple 99.92%
# 6 Apple 99.92%
# 7 Apple 64.02%
# === A frame took 1.623 seconds
# 0 Oriental melon 97.47%
# 1 Oriental melon 89.40%
# 2 Tomato 99.97%
# 3 Tomato 99.88%
# 4 Apple 99.91%
# 5 Apple 99.91%
# 6 Apple 99.90%
# 7 Apple 86.18%
# === A frame took 1.620 seconds
# 0 Oriental melon 97.65%
# 1 Oriental melon 94.16%
# 2 Tomato 99.97%
# 3 Tomato 99.88%
# 4 Tomato 77.20%
# 5 Apple 99.94%
# 6 Apple 99.92%
# 7 Apple 99.91%
# === A frame took 1.588 seconds
# 0 Oriental melon 98.46%
# 1 Oriental melon 95.99%
# 2 Tomato 99.97%
# 3 Tomato 99.88%
# 4 Apple 99.94%
# 5 Apple 99.92%
# 6 Apple 99.92%
# === A frame took 1.621 seconds
# 0 Oriental melon 96.66%
# 1 Oriental melon 95.25%
# 2 Tomato 99.97%
# 3 Tomato 99.90%
# 4 Apple 99.94%
# 5 Apple 99.92%
# 6 Apple 99.91%
# === A frame took 1.641 seconds
# 0 Oriental melon 96.98%
# 1 Oriental melon 94.67%
# 2 Tomato 99.96%
# 3 Tomato 99.90%
# 4 Apple 99.94%
# 5 Apple 99.92%
# 6 Apple 99.91%
# === A frame took 1.602 seconds
# 0 Oriental melon 97.12%
# 1 Oriental melon 95.35%
# 2 Tomato 99.97%
# 3 Tomato 99.90%
# 4 Apple 99.93%
# 5 Apple 99.92%
# 6 Apple 99.92%
# === A frame took 1.662 seconds
# 0 Oriental melon 96.87%
# 1 Oriental melon 95.62%
# 2 Tomato 99.97%
# 3 Tomato 99.90%
# 4 Apple 99.93%
# 5 Apple 99.92%
# 6 Apple 99.91%
# === A frame took 1.654 seconds
# 0 Oriental melon 98.06%
# 1 Oriental melon 96.00%
# 2 Tomato 99.97%
# 3 Tomato 99.90%
# 4 Apple 99.94%
# 5 Apple 99.92%
# 6 Apple 99.91%
# === A frame took 1.598 seconds
# 0 Oriental melon 97.86%
# 1 Oriental melon 96.35%
# 2 Tomato 99.97%
# 3 Tomato 99.91%
# 4 Apple 99.95%
# 5 Apple 99.92%
# 6 Apple 99.92%
# === A frame took 1.626 seconds
# 0 Oriental melon 97.09%
# 1 Oriental melon 94.85%
# 2 Tomato 99.97%
# 3 Tomato 99.91%
# 4 Apple 99.95%
# 5 Apple 99.92%
# 6 Apple 99.92%
# === A frame took 1.631 seconds
# 0 Oriental melon 94.40%
# 1 Oriental melon 91.06%
# 2 Tomato 99.97%
# 3 Tomato 99.92%
# 4 Apple 99.94%
# 5 Apple 99.92%
# 6 Apple 99.91%
# === A frame took 1.622 seconds
# 0 Oriental melon 96.08%
# 1 Oriental melon 93.97%
# 2 Tomato 99.97%
# 3 Tomato 99.92%
# 4 Apple 99.95%
# 5 Apple 99.92%
# 6 Apple 99.90%
# === A frame took 1.620 seconds
# 0 Oriental melon 96.77%
# 1 Oriental melon 94.92%
# 2 Tomato 99.97%
# 3 Tomato 99.92%
# 4 Apple 99.95%
# 5 Apple 99.92%
# 6 Apple 99.90%
# === A frame took 1.609 seconds
# 0 Oriental melon 98.30%
# 1 Oriental melon 97.28%
# 2 Tomato 99.97%
# 3 Tomato 99.92%
# 4 Apple 99.95%
# 5 Apple 99.92%
# 6 Apple 99.90%
# === A frame took 1.647 seconds
# 0 Oriental melon 97.98%
# 1 Oriental melon 97.45%
# 2 Tomato 99.97%
# 3 Tomato 99.92%
# 4 Apple 99.95%
# 5 Apple 99.92%
# 6 Apple 99.89%
# === A frame took 1.621 seconds
# 0 Oriental melon 96.92%
# 1 Oriental melon 96.58%
# 2 Tomato 99.96%
# 3 Tomato 99.92%
# 4 Apple 99.95%
# 5 Apple 99.92%
# 6 Apple 99.90%
# === A frame took 1.647 seconds
# 0 Oriental melon 97.76%
# 1 Oriental melon 96.78%
# 2 Tomato 99.96%
# 3 Tomato 99.92%
# 4 Apple 99.95%
# 5 Apple 99.92%
# 6 Apple 99.92%
# === A frame took 1.610 seconds
# 0 Oriental melon 96.96%
# 1 Oriental melon 96.16%
# 2 Tomato 99.96%
# 3 Tomato 99.93%
# 4 Apple 99.95%
# 5 Apple 99.93%
# 6 Apple 99.92%
# === A frame took 1.628 seconds
# 0 Oriental melon 97.03%
# 1 Oriental melon 96.23%
# 2 Tomato 99.96%
# 3 Tomato 99.93%
# 4 Apple 99.94%
# 5 Apple 99.92%
# 6 Apple 99.92%
# === A frame took 1.636 seconds
# 0 Oriental melon 97.07%
# 1 Oriental melon 96.40%
# 2 Tomato 99.96%
# 3 Tomato 99.92%
# 4 Apple 99.95%
# 5 Apple 99.92%
# 6 Apple 99.90%
# === A frame took 1.601 seconds
# 0 Oriental melon 97.67%
# 1 Oriental melon 95.93%
# 2 Tomato 99.96%
# 3 Tomato 99.92%
# 4 Apple 99.95%
# 5 Apple 99.92%
# 6 Apple 99.89%
# === A frame took 1.624 seconds
# 0 Oriental melon 96.52%
# 1 Oriental melon 96.35%
# 2 Tomato 99.95%
# 3 Tomato 99.92%
# 4 Apple 99.95%
# 5 Apple 99.93%
# 6 Apple 99.90%
# === A frame took 1.637 seconds
# 0 Oriental melon 97.32%
# 1 Oriental melon 97.22%
# 2 Tomato 99.94%
# 3 Tomato 99.91%
# 4 Apple 99.95%
# 5 Apple 99.93%
# 6 Apple 99.90%
# === A frame took 1.657 seconds
# 0 Oriental melon 96.39%
# 1 Oriental melon 95.34%
# 2 Tomato 99.94%
# 3 Tomato 99.92%
# 4 Apple 99.95%
# 5 Apple 99.93%
# 6 Apple 99.90%
# === A frame took 1.621 seconds
# 0 Oriental melon 97.04%
# 1 Oriental melon 96.49%
# 2 Tomato 99.94%
# 3 Tomato 99.91%
# 4 Apple 99.95%
# 5 Apple 99.93%
# 6 Apple 99.89%
# === A frame took 1.603 seconds
# 0 Oriental melon 97.29%
# 1 Oriental melon 96.99%
# 2 Tomato 99.94%
# 3 Tomato 99.91%
# 4 Apple 99.95%
# 5 Apple 99.93%
# 6 Apple 99.90%
# === A frame took 1.612 seconds
# 0 Oriental melon 96.86%
# 1 Oriental melon 96.51%
# 2 Tomato 99.92%
# 3 Tomato 99.92%
# 4 Apple 99.95%
# 5 Apple 99.93%
# 6 Apple 99.90%
# === A frame took 1.647 seconds
# 0 Oriental melon 97.50%
# 1 Oriental melon 95.36%
# 2 Tomato 99.92%
# 3 Tomato 99.91%
# 4 Apple 99.95%
# 5 Apple 99.93%
# 6 Apple 99.89%
# === A frame took 1.651 seconds
# 0 Oriental melon 97.81%
# 1 Oriental melon 95.26%
# 2 Tomato 99.92%
# 3 Tomato 99.91%
# 4 Apple 99.95%
# 5 Apple 99.93%
# 6 Apple 99.90%
# === A frame took 1.640 seconds
# 0 Oriental melon 97.40%
# 1 Oriental melon 95.67%
# 2 Tomato 99.92%
# 3 Tomato 99.91%
# 4 Apple 99.94%
# 5 Apple 99.93%
# 6 Apple 99.89%
# === A frame took 1.625 seconds
# 0 Oriental melon 95.87%
# 1 Oriental melon 95.02%
# 2 Tomato 99.92%
# 3 Tomato 99.91%
# 4 Apple 99.93%
# 5 Apple 99.93%
# 6 Apple 99.88%
# === A frame took 1.648 seconds
# 0 Oriental melon 96.45%
# 1 Oriental melon 94.88%
# 2 Tomato 99.92%
# 3 Tomato 99.90%
# 4 Apple 99.94%
# 5 Apple 99.93%
# 6 Apple 99.89%
# === A frame took 1.628 seconds
# 0 Oriental melon 94.00%
# 1 Oriental melon 89.43%
# 2 Tomato 99.93%
# 3 Tomato 99.89%
# 4 Apple 99.93%
# 5 Apple 99.93%
# 6 Apple 99.90%
# === A frame took 1.658 seconds
# 0 Oriental melon 95.89%
# 1 Oriental melon 85.99%
# 2 Tomato 99.92%
# 3 Tomato 99.89%
# 4 Apple 99.93%
# 5 Apple 99.93%
# 6 Apple 99.91%
# === A frame took 1.665 seconds
# 0 Oriental melon 97.02%
# 1 Oriental melon 84.89%
# 2 Tomato 99.93%
# 3 Tomato 99.90%
# 4 Apple 99.93%
# 5 Apple 99.93%
# 6 Apple 99.90%
# === A frame took 1.620 seconds
# 0 Oriental melon 97.55%
# 1 Oriental melon 86.44%
# 2 Tomato 99.93%
# 3 Tomato 99.89%
# 4 Apple 99.94%
# 5 Apple 99.93%
# 6 Apple 99.91%
# === A frame took 1.626 seconds
# 0 Oriental melon 97.36%
# 1 Oriental melon 84.36%
# 2 Tomato 99.93%
# 3 Tomato 99.89%
# 4 Tomato 51.53%
# 5 Apple 99.93%
# 6 Apple 99.93%
# 7 Apple 99.92%
# === A frame took 1.643 seconds
# 0 Oriental melon 98.03%
# 1 Oriental melon 85.65%
# 2 Tomato 99.93%
# 3 Tomato 99.91%
# 4 Apple 99.93%
# 5 Apple 99.93%
# 6 Apple 99.91%
# === A frame took 1.584 seconds
# 0 Oriental melon 97.62%
# 1 Oriental melon 87.17%
# 2 Tomato 99.93%
# 3 Tomato 99.90%
# 4 Apple 99.93%
# 5 Apple 99.93%
# 6 Apple 99.91%
# === A frame took 1.643 seconds
# 0 Oriental melon 97.59%
# 1 Oriental melon 83.54%
# 2 Tomato 99.93%
# 3 Tomato 99.89%
# 4 Apple 99.93%
# 5 Apple 99.93%
# 6 Apple 99.92%
# === A frame took 1.688 seconds
# 0 Oriental melon 96.34%
# 1 Oriental melon 79.42%
# 2 Tomato 99.93%
# 3 Tomato 99.88%
# 4 Tomato 55.58%
# 5 Apple 99.93%
# 6 Apple 99.92%
# 7 Apple 99.92%
# === A frame took 1.661 seconds
# 0 Oriental melon 96.02%
# 1 Oriental melon 75.61%
# 2 Tomato 99.92%
# 3 Tomato 99.87%
# 4 Tomato 60.50%
# 5 Apple 99.92%
# 6 Apple 99.91%
# 7 Apple 99.91%
# === A frame took 1.620 seconds
# 0 Oriental melon 97.75%
# 1 Oriental melon 88.98%
# 2 Tomato 99.92%
# 3 Tomato 99.87%
# 4 Apple 99.93%
# 5 Apple 99.91%
# 6 Apple 99.91%
# === A frame took 1.613 seconds
# 0 Oriental melon 96.42%
# 1 Oriental melon 86.65%
# 2 Tomato 99.92%
# 3 Tomato 99.87%
# 4 Apple 99.93%
# 5 Apple 99.92%
# 6 Apple 99.91%
# === A frame took 1.641 seconds
# 0 Oriental melon 95.35%
# 1 Oriental melon 86.46%
# 2 Tomato 99.91%
# 3 Tomato 99.84%
# 4 Apple 99.93%
# 5 Apple 99.92%
# 6 Apple 99.91%
# === A frame took 1.592 seconds
# 0 Oriental melon 97.22%
# 1 Oriental melon 89.82%
# 2 Tomato 99.91%
# 3 Tomato 99.88%
# 4 Tomato 99.26%
# 5 Apple 99.93%
# 6 Apple 99.92%
# 7 Apple 99.90%
# === A frame took 1.663 seconds
# 0 Oriental melon 98.46%
# 1 Oriental melon 92.20%
# 2 Tomato 99.91%
# 3 Tomato 99.88%
# 4 Tomato 99.54%
# 5 Apple 99.93%
# 6 Apple 99.92%
# 7 Apple 99.92%
# === A frame took 1.655 seconds
# 0 Oriental melon 96.09%
# 1 Oriental melon 90.25%
# 2 Tomato 99.90%
# 3 Tomato 99.90%
# 4 Tomato 98.66%
# 5 Apple 99.93%
# 6 Apple 99.93%
# 7 Apple 99.91%
# === A frame took 1.624 seconds
# 0 Oriental melon 97.69%
# 1 Oriental melon 92.46%
# 2 Tomato 99.91%
# 3 Tomato 99.91%
# 4 Tomato 99.81%
# 5 Apple 99.94%
# 6 Apple 99.93%
# 7 Apple 99.92%
# === A frame took 1.634 seconds
# 0 Oriental melon 96.77%
# 1 Oriental melon 90.58%
# 2 Tomato 99.91%
# 3 Tomato 99.91%
# 4 Tomato 99.82%
# 5 Apple 99.94%
# 6 Apple 99.93%
# 7 Apple 99.92%
# === A frame took 1.630 seconds
# 0 Oriental melon 96.21%
# 1 Oriental melon 91.60%
# 2 Tomato 99.91%
# 3 Tomato 99.90%
# 4 Tomato 99.80%
# 5 Apple 99.94%
# 6 Apple 99.93%
# 7 Apple 99.91%
# === A frame took 1.637 seconds
# 0 Oriental melon 96.69%
# 1 Oriental melon 94.55%
# 2 Tomato 99.92%
# 3 Tomato 99.91%
# 4 Tomato 94.40%
# 5 Apple 99.94%
# 6 Apple 99.92%
# 7 Apple 99.90%
# 8 Apple 53.38%
# === A frame took 1.684 seconds
# 0 Oriental melon 97.43%
# 1 Oriental melon 93.93%
# 2 Tomato 99.92%
# 3 Tomato 99.90%
# 4 Apple 99.94%
# 5 Apple 99.90%
# 6 Apple 99.90%
# 7 Apple 84.97%
# === A frame took 1.663 seconds
# 0 Oriental melon 96.09%
# 1 Oriental melon 92.58%
# 2 Tomato 99.91%
# 3 Tomato 99.87%
# 4 Apple 99.94%
# 5 Apple 99.91%
# 6 Apple 99.85%
# 7 Apple 99.02%
# === A frame took 1.661 seconds
# 0 Oriental melon 97.88%
# 1 Oriental melon 95.18%
# 2 Tomato 99.92%
# 3 Tomato 99.87%
# 4 Apple 99.94%
# 5 Apple 99.89%
# 6 Apple 99.74%
# 7 Apple 99.33%
# === A frame took 1.662 seconds
# 0 Oriental melon 95.87%
# 1 Oriental melon 94.74%
# 2 Tomato 99.92%
# 3 Tomato 99.87%
# 4 Tomato 99.18%
# 5 Apple 99.94%
# 6 Apple 99.89%
# 7 Apple 99.77%
# 8 Apple 96.05%
# === A frame took 1.632 seconds
# 0 Oriental melon 97.47%
# 1 Oriental melon 96.09%
# 2 Tomato 99.92%
# 3 Tomato 99.88%
# 4 Tomato 96.60%
# 5 Apple 99.95%
# 6 Apple 99.90%
# 7 Apple 99.78%
# 8 Apple 84.95%
# === A frame took 1.666 seconds
# 0 Oriental melon 96.27%
# 1 Oriental melon 95.10%
# 2 Tomato 99.92%
# 3 Tomato 99.88%
# 4 Tomato 95.89%
# 5 Tomato 66.08%
# 6 Apple 99.94%
# 7 Apple 99.91%
# 8 Apple 99.74%
# === A frame took 1.679 seconds
# 0 Oriental melon 94.70%
# 1 Oriental melon 67.89%
# 2 Tomato 99.92%
# 3 Tomato 99.90%
# 4 Tomato 99.55%
# 5 Apple 99.94%
# 6 Apple 99.91%
# 7 Apple 99.59%
# === A frame took 1.649 seconds
# 0 Oriental melon 95.29%
# 1 Tomato 99.91%
# 2 Tomato 99.91%
# 3 Tomato 99.67%
# 4 Apple 99.94%
# 5 Apple 99.92%
# 6 Apple 99.90%
# === A frame took 1.635 seconds
# 0 Oriental melon 96.26%
# 1 Tomato 99.92%
# 2 Tomato 99.91%
# 3 Tomato 99.71%
# 4 Apple 99.94%
# 5 Apple 99.92%
# 6 Apple 99.92%
# === A frame took 1.621 seconds
# 0 Oriental melon 91.91%
# 1 Tomato 99.93%
# 2 Tomato 99.91%
# 3 Tomato 99.86%
# 4 Apple 99.94%
# 5 Apple 99.92%
# 6 Apple 99.91%
# === A frame took 1.640 seconds
# 0 Oriental melon 94.47%
# 1 Tomato 99.93%
# 2 Tomato 99.90%
# 3 Tomato 99.80%
# 4 Tomato 55.52%
# 5 Apple 99.94%
# 6 Apple 99.92%
# 7 Apple 99.92%
# === A frame took 1.663 seconds
# 0 Oriental melon 77.23%
# 1 Tomato 99.93%
# 2 Tomato 99.91%
# 3 Tomato 99.73%
# 4 Tomato 79.69%
# 5 Tomato 71.25%
# 6 Apple 99.92%
# 7 Apple 99.89%
# 8 Apple 99.89%
# === A frame took 1.650 seconds
# 0 Oriental melon 86.87%
# 1 Tomato 99.94%
# 2 Tomato 99.91%
# 3 Tomato 99.82%
# 4 Tomato 83.25%
# 5 Tomato 50.34%
# 6 Apple 99.92%
# 7 Apple 99.89%
# 8 Apple 99.88%
# === A frame took 1.645 seconds
# 0 Oriental melon 90.53%
# 1 Tomato 99.91%
# 2 Tomato 99.90%
# 3 Tomato 99.90%
# 4 Tomato 75.44%
# 5 Apple 99.91%
# 6 Apple 99.90%
# 7 Apple 99.89%
# === A frame took 1.651 seconds
# 0 Oriental melon 89.73%
# 1 Tomato 99.92%
# 2 Tomato 99.89%
# 3 Tomato 99.66%
# 4 Tomato 81.06%
# 5 Apple 99.90%
# 6 Apple 99.90%
# 7 Apple 99.88%
# === A frame took 1.656 seconds
# 0 Oriental melon 95.95%
# 1 Tomato 99.94%
# 2 Tomato 99.89%
# 3 Tomato 98.66%
# 4 Tomato 70.88%
# 5 Apple 99.90%
# 6 Apple 99.89%
# 7 Apple 99.88%
# === A frame took 1.640 seconds
# 0 Oriental melon 95.58%
# 1 Tomato 99.95%
# 2 Tomato 99.90%
# 3 Tomato 99.36%
# 4 Tomato 67.21%
# 5 Apple 99.92%
# 6 Apple 99.91%
# 7 Apple 99.88%
# === A frame took 1.644 seconds
# 0 Oriental melon 96.04%
# 1 Tomato 99.95%
# 2 Tomato 99.90%
# 3 Tomato 99.26%
# 4 Tomato 70.15%
# 5 Apple 99.92%
# 6 Apple 99.90%
# 7 Apple 99.89%
# === A frame took 1.678 seconds
# 0 Oriental melon 93.78%
# 1 Tomato 99.95%
# 2 Tomato 99.90%
# 3 Tomato 99.57%
# 4 Apple 99.93%
# 5 Apple 99.91%
# 6 Apple 99.88%
# 7 Apple 62.48%
# === A frame took 1.669 seconds
# 0 Oriental melon 91.77%
# 1 Oriental melon 51.99%
# 2 Tomato 99.95%
# 3 Tomato 99.90%
# 4 Tomato 99.43%
# 5 Apple 99.93%
# 6 Apple 99.91%
# 7 Apple 99.90%
# 8 Apple 68.15%
# === A frame took 1.660 seconds
# 0 Oriental melon 90.03%
# 1 Tomato 99.94%
# 2 Tomato 99.91%
# 3 Tomato 99.42%
# 4 Tomato 84.22%
# 5 Apple 99.94%
# 6 Apple 99.91%
# 7 Apple 99.89%
# 8 Apple 77.98%
# === A frame took 1.654 seconds
# 0 Oriental melon 89.36%
# 1 Tomato 99.94%
# 2 Tomato 99.91%
# 3 Tomato 99.23%
# 4 Tomato 70.96%
# 5 Apple 99.93%
# 6 Apple 99.92%
# 7 Apple 99.87%
# 8 Apple 72.52%
# === A frame took 1.637 seconds
# 0 Oriental melon 88.09%
# 1 Tomato 99.94%
# 2 Tomato 99.92%
# 3 Tomato 99.27%
# 4 Apple 99.93%
# 5 Apple 99.92%
# 6 Apple 99.87%
# 7 Apple 70.16%
# === A frame took 1.650 seconds
# 0 Oriental melon 88.64%
# 1 Tomato 99.95%
# 2 Tomato 99.92%
# 3 Tomato 99.48%
# 4 Apple 99.92%
# 5 Apple 99.91%
# 6 Apple 99.88%
# 7 Apple 87.37%
# === A frame took 1.637 seconds
# 0 Oriental melon 92.90%
# 1 Tomato 99.95%
# 2 Tomato 99.91%
# 3 Tomato 99.45%
# 4 Tomato 63.16%
# 5 Apple 99.91%
# 6 Apple 99.90%
# 7 Apple 99.85%
# 8 Apple 87.14%
# === A frame took 1.664 seconds
# 0 Oriental melon 90.61%
# 1 Tomato 99.94%
# 2 Tomato 99.91%
# 3 Tomato 99.52%
# 4 Tomato 58.55%
# 5 Apple 99.89%
# 6 Apple 99.89%
# 7 Apple 99.81%
# 8 Apple 75.16%
# === A frame took 1.657 seconds
# 0 Oriental melon 97.24%
# 1 Tomato 99.93%
# 2 Tomato 99.92%
# 3 Tomato 99.66%
# 4 Tomato 55.14%
# 5 Apple 99.90%
# 6 Apple 99.89%
# 7 Apple 99.82%
# 8 Apple 76.01%
# === A frame took 1.651 seconds
# 0 Oriental melon 98.66%
# 1 Tomato 99.94%
# 2 Tomato 99.92%
# 3 Tomato 99.90%
# 4 Tomato 70.02%
# 5 Tomato 57.23%
# 6 Apple 99.89%
# 7 Apple 99.89%
# 8 Apple 99.80%
# 9 Apple 91.98%
# === A frame took 1.659 seconds
# 0 Oriental melon 97.67%
# 1 Tomato 99.93%
# 2 Tomato 99.92%
# 3 Tomato 99.92%
# 4 Tomato 77.77%
# 5 Apple 99.91%
# 6 Apple 99.89%
# 7 Apple 99.71%
# 8 Apple 91.72%
# === A frame took 1.635 seconds
# 0 Oriental melon 96.78%
# 1 Tomato 99.93%
# 2 Tomato 99.93%
# 3 Tomato 99.92%
# 4 Tomato 96.21%
# 5 Tomato 81.63%
# 6 Apple 99.92%
# 7 Apple 99.90%
# 8 Apple 99.56%
# 9 Apple 75.36%
# === A frame took 1.642 seconds
# 0 Oriental melon 97.78%
# 1 Tomato 99.95%
# 2 Tomato 99.92%
# 3 Tomato 99.92%
# 4 Tomato 95.24%
# 5 Tomato 92.37%
# 6 Tomato 75.36%
# 7 Apple 99.90%
# 8 Apple 99.88%
# 9 Apple 99.71%
# 10 Apple 57.87%
# === A frame took 1.674 seconds
# 0 Oriental melon 97.65%
# 1 Tomato 99.95%
# 2 Tomato 99.93%
# 3 Tomato 99.92%
# 4 Tomato 99.27%
# 5 Tomato 84.20%
# 6 Apple 99.89%
# 7 Apple 99.89%
# 8 Apple 99.88%
# === A frame took 1.664 seconds
# 0 Oriental melon 98.27%
# 1 Tomato 99.96%
# 2 Tomato 99.94%
# 3 Tomato 99.92%
# 4 Tomato 99.19%
# 5 Tomato 84.60%
# 6 Apple 99.90%
# 7 Apple 99.87%
# 8 Apple 99.82%
# === A frame took 1.665 seconds
# 0 Oriental melon 98.49%
# 1 Tomato 99.96%
# 2 Tomato 99.94%
# 3 Tomato 99.92%
# 4 Tomato 98.67%
# 5 Tomato 76.45%
# 6 Apple 99.90%
# 7 Apple 99.90%
# 8 Apple 99.88%
# === A frame took 1.642 seconds
# 0 Oriental melon 98.83%
# 1 Oriental melon 52.24%
# 2 Tomato 99.96%
# 3 Tomato 99.92%
# 4 Tomato 99.92%
# 5 Tomato 85.54%
# 6 Tomato 54.17%
# 7 Apple 99.89%
# 8 Apple 99.89%
# 9 Apple 99.87%
# === A frame took 1.656 seconds
# 0 Oriental melon 96.27%
# 1 Oriental melon 73.72%
# 2 Tomato 99.96%
# 3 Tomato 99.93%
# ...
# 1 Oriental melon 63.99%
# 2 Tomato 99.97%
# 3 Tomato 99.87%
# 4 Tomato 99.84%
# 5 Tomato 99.83%
# 6 Tomato 97.04%
# 7 Tomato 96.87%
# 8 Tomato 78.11%
# 9 Apple 99.83%
# 10 Apple 99.62%
# === A frame took 1.589 seconds
# 0 Oriental melon 89.30%
# 1 Oriental melon 75.26%
# 2 Tomato 99.97%
# 3 Tomato 99.90%
# 4 Tomato 99.88%
# 5 Tomato 99.86%
# 6 Tomato 99.72%
# 7 Tomato 93.67%
# 8 Tomato 82.21%
# 9 Apple 99.85%
# 10 Apple 98.14%
# === A frame took 1.582 seconds
# 0 Oriental melon 95.84%
# 1 Oriental melon 75.47%
# 2 Tomato 99.97%
# 3 Tomato 99.90%
# 4 Tomato 99.88%
# 5 Tomato 99.87%
# 6 Tomato 99.60%
# 7 Tomato 93.30%
# 8 Tomato 88.95%
# 9 Apple 99.87%
# 10 Apple 98.62%
# === A frame took 1.616 seconds
# 0 Oriental melon 91.36%
# 1 Oriental melon 74.01%
# 2 Tomato 99.97%
# 3 Tomato 99.90%
# 4 Tomato 99.88%
# 5 Tomato 99.86%
# 6 Tomato 98.91%
# 7 Tomato 94.57%
# 8 Tomato 82.04%
# 9 Apple 99.87%
# 10 Apple 98.62%
# === A frame took 1.613 seconds
# 0 Oriental melon 88.84%
# 1 Oriental melon 72.25%
# 2 Tomato 99.97%
# 3 Tomato 99.91%
# 4 Tomato 99.88%
# 5 Tomato 99.86%
# 6 Tomato 98.18%
# 7 Tomato 95.35%
# 8 Tomato 69.78%
# 9 Apple 99.86%
# 10 Apple 99.33%
# === A frame took 1.602 seconds
# 0 Oriental melon 92.79%
# 1 Oriental melon 63.06%
# 2 Tomato 99.97%
# 3 Tomato 99.91%
# 4 Tomato 99.89%
# 5 Tomato 99.85%
# 6 Tomato 99.81%
# 7 Tomato 96.45%
# 8 Tomato 62.62%
# 9 Apple 99.80%
# 10 Apple 99.45%
# === A frame took 1.609 seconds
# 0 Oriental melon 93.24%
# 1 Oriental melon 67.60%
# 2 Tomato 99.97%
# 3 Tomato 99.91%
# 4 Tomato 99.91%
# 5 Tomato 99.85%
# 6 Tomato 99.83%
# 7 Tomato 95.00%
# 8 Tomato 50.73%
# 9 Apple 99.79%
# 10 Apple 99.72%
# === A frame took 1.619 seconds
# 0 Oriental melon 97.95%
# 1 Oriental melon 85.69%
# 2 Tomato 99.97%
# 3 Tomato 99.92%
# 4 Tomato 99.91%
# 5 Tomato 99.89%
# 6 Tomato 99.87%
# 7 Tomato 87.34%
# 8 Apple 99.86%
# 9 Apple 99.85%
# === A frame took 1.622 seconds
# 0 Oriental melon 97.51%
# 1 Oriental melon 81.94%
# 2 Tomato 99.97%
# 3 Tomato 99.92%
# 4 Tomato 99.91%
# 5 Tomato 99.87%
# 6 Tomato 99.87%
# 7 Tomato 89.20%
# 8 Tomato 55.31%
# 9 Apple 99.88%
# 10 Apple 99.87%
# === A frame took 1.630 seconds
# 0 Oriental melon 97.28%
# 1 Oriental melon 76.81%
# 2 Tomato 99.97%
# 3 Tomato 99.92%
# 4 Tomato 99.90%
# 5 Tomato 99.88%
# 6 Tomato 99.77%
# 7 Tomato 93.54%
# 8 Tomato 54.31%
# 9 Tomato 50.21%
# 10 Apple 99.89%
# 11 Apple 99.87%
# === A frame took 1.569 seconds
# 0 Oriental melon 95.73%
# 1 Oriental melon 77.74%
# 2 Tomato 99.97%
# 3 Tomato 99.91%
# 4 Tomato 99.91%
# 5 Tomato 99.88%
# 6 Tomato 99.86%
# 7 Tomato 92.03%
# 8 Apple 99.87%
# 9 Apple 99.86%
# === A frame took 1.591 seconds
# 0 Oriental melon 98.18%
# 1 Oriental melon 87.02%
# 2 Tomato 99.97%
# 3 Tomato 99.92%
# 4 Tomato 99.90%
# 5 Tomato 99.88%
# 6 Tomato 99.86%
# 7 Tomato 85.16%
# 8 Tomato 50.20%
# 9 Apple 99.87%
# 10 Apple 99.86%
# === A frame took 1.584 seconds
# 0 Oriental melon 95.22%
# 1 Oriental melon 82.33%
# 2 Tomato 99.96%
# 3 Tomato 99.92%
# 4 Tomato 99.89%
# 5 Tomato 99.86%
# 6 Tomato 99.81%
# 7 Tomato 88.01%
# 8 Apple 99.87%
# 9 Apple 99.87%
# === A frame took 1.607 seconds
# 0 Oriental melon 95.87%
# 1 Oriental melon 91.09%
# 2 Tomato 99.96%
# 3 Tomato 99.92%
# 4 Tomato 99.90%
# 5 Tomato 99.88%
# 6 Tomato 99.81%
# 7 Tomato 81.32%
# 8 Apple 99.88%
# 9 Apple 99.85%
# === A frame took 1.646 seconds
# 0 Oriental melon 96.59%
# 1 Oriental melon 92.68%
# 2 Tomato 99.96%
# 3 Tomato 99.92%
# 4 Tomato 99.89%
# 5 Tomato 99.86%
# 6 Tomato 99.82%
# 7 Tomato 79.03%
# 8 Apple 99.87%
# 9 Apple 99.80%
# === A frame took 1.601 seconds
# 0 Oriental melon 96.52%
# 1 Oriental melon 91.70%
# 2 Tomato 99.96%
# 3 Tomato 99.92%
# 4 Tomato 99.89%
# 5 Tomato 99.82%
# 6 Tomato 99.80%
# 7 Tomato 83.84%
# 8 Apple 99.88%
# 9 Apple 99.84%
# === A frame took 1.577 seconds
# 0 Oriental melon 97.41%
# 1 Oriental melon 84.47%
# 2 Tomato 99.96%
# 3 Tomato 99.92%
# 4 Tomato 99.87%
# 5 Tomato 99.78%
# 6 Tomato 99.78%
# 7 Tomato 89.68%
# 8 Apple 99.87%
# 9 Apple 99.85%
# === A frame took 1.627 seconds
# 0 Oriental melon 94.23%
# 1 Oriental melon 83.15%
# 2 Tomato 99.97%
# 3 Tomato 99.93%
# 4 Tomato 99.83%
# 5 Tomato 99.81%
# 6 Tomato 99.81%
# 7 Tomato 95.14%
# 8 Tomato 59.30%
# 9 Apple 99.85%
# 10 Apple 99.85%
# === A frame took 1.613 seconds
# 0 Oriental melon 86.24%
# 1 Oriental melon 77.20%
# 2 Tomato 99.97%
# 3 Tomato 99.94%
# 4 Tomato 99.89%
# 5 Tomato 99.86%
# 6 Tomato 99.80%
# 7 Tomato 95.76%
# 8 Apple 99.85%
# 9 Apple 99.85%
# === A frame took 1.561 seconds
# 0 Oriental melon 90.39%
# 1 Oriental melon 72.93%
# 2 Tomato 99.97%
# 3 Tomato 99.94%
# 4 Tomato 99.88%
# 5 Tomato 99.84%
# 6 Tomato 99.83%
# 7 Tomato 96.75%
# 8 Apple 99.85%
# 9 Apple 99.84%
# === A frame took 1.619 seconds
# 0 Oriental melon 93.72%
# 1 Oriental melon 77.05%
# 2 Tomato 99.97%
# 3 Tomato 99.94%
# 4 Tomato 99.86%
# 5 Tomato 99.84%
# 6 Tomato 99.82%
# 7 Tomato 95.95%
# 8 Apple 99.84%
# 9 Apple 99.83%
# === A frame took 1.586 seconds
# 0 Oriental melon 94.61%
# 1 Oriental melon 83.41%
# 2 Tomato 99.97%
# 3 Tomato 99.94%
# 4 Tomato 99.85%
# 5 Tomato 99.83%
# 6 Tomato 99.82%
# 7 Tomato 94.61%
# 8 Apple 99.83%
# 9 Apple 99.83%
# === A frame took 1.592 seconds
# 0 Oriental melon 94.95%
# 1 Oriental melon 86.20%
# 2 Tomato 99.97%
# 3 Tomato 99.94%
# 4 Tomato 99.84%
# 5 Tomato 99.84%
# 6 Tomato 99.84%
# 7 Tomato 93.89%
# 8 Apple 99.83%
# 9 Apple 99.82%
# === A frame took 1.540 seconds
# 0 Oriental melon 94.23%
# 1 Oriental melon 80.80%
# 2 Tomato 99.97%
# 3 Tomato 99.94%
# 4 Tomato 99.83%
# 5 Tomato 99.82%
# 6 Tomato 99.79%
# 7 Tomato 92.96%
# 8 Apple 99.79%
# 9 Apple 99.79%
# === A frame took 1.597 seconds
# 0 Oriental melon 93.43%
# 1 Oriental melon 84.31%
# 2 Tomato 99.97%
# 3 Tomato 99.94%
# 4 Tomato 99.86%
# 5 Tomato 99.84%
# 6 Tomato 99.80%
# 7 Tomato 92.63%
# 8 Apple 99.81%
# 9 Apple 99.74%
# === A frame took 1.567 seconds
# 0 Oriental melon 94.83%
# 1 Oriental melon 76.44%
# 2 Tomato 99.96%
# 3 Tomato 99.94%
# 4 Tomato 99.86%
# 5 Tomato 99.78%
# 6 Tomato 99.77%
# 7 Tomato 95.02%
# 8 Apple 99.76%
# 9 Apple 99.56%
# === A frame took 1.591 seconds
# 0 Oriental melon 97.04%
# 1 Oriental melon 89.20%
# 2 Tomato 99.97%
# 3 Tomato 99.95%
# 4 Tomato 99.87%
# 5 Tomato 99.77%
# 6 Tomato 99.76%
# 7 Tomato 90.31%
# 8 Apple 99.78%
# 9 Apple 99.44%
# 10 Apple 53.12%
# === A frame took 1.609 seconds
# 0 Oriental melon 91.58%
# 1 Oriental melon 82.95%
# 2 Tomato 99.97%
# 3 Tomato 99.95%
# 4 Tomato 99.86%
# 5 Tomato 99.81%
# 6 Tomato 99.77%
# 7 Tomato 93.44%
# 8 Apple 99.75%
# 9 Apple 99.64%
# 10 Apple 86.09%
# === A frame took 1.621 seconds
# 0 Oriental melon 93.15%
# 1 Oriental melon 79.26%
# 2 Tomato 99.96%
# 3 Tomato 99.95%
# 4 Tomato 99.85%
# 5 Tomato 99.81%
# 6 Tomato 99.78%
# 7 Tomato 93.91%
# 8 Apple 99.73%
# 9 Apple 99.71%
# 10 Apple 57.82%
# === A frame took 1.643 seconds
# 0 Oriental melon 91.20%
# 1 Oriental melon 71.65%
# 2 Tomato 99.97%
# 3 Tomato 99.95%
# 4 Tomato 99.89%
# 5 Tomato 99.84%
# 6 Tomato 99.78%
# 7 Tomato 95.10%
# 8 Apple 99.74%
# 9 Apple 99.60%
# 10 Apple 87.21%
# === A frame took 1.631 seconds
# 0 Oriental melon 94.85%
# 1 Oriental melon 81.09%
# 2 Tomato 99.97%
# 3 Tomato 99.95%
# 4 Tomato 99.92%
# 5 Tomato 99.90%
# 6 Tomato 99.83%
# 7 Tomato 94.01%
# 8 Apple 99.76%
# 9 Apple 97.66%
# 10 Apple 97.52%
# === A frame took 1.609 seconds
# 0 Oriental melon 96.88%
# 1 Oriental melon 76.08%
# 2 Tomato 99.96%
# 3 Tomato 99.95%
# 4 Tomato 99.94%
# 5 Tomato 99.91%
# 6 Tomato 99.91%
# 7 Tomato 95.60%
# 8 Tomato 82.34%
# 9 Apple 99.74%
# 10 Apple 97.59%
# 11 Apple 97.44%
# 12 Apple 51.54%
# === A frame took 1.610 seconds
# 0 Oriental melon 95.58%
# 1 Oriental melon 79.94%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.93%
# 6 Tomato 99.91%
# 7 Tomato 97.97%
# 8 Apple 99.72%
# 9 Apple 99.40%
# 10 Apple 97.73%
# === A frame took 1.591 seconds
# 0 Oriental melon 93.64%
# 1 Oriental melon 69.91%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.93%
# 6 Tomato 99.91%
# 7 Tomato 98.63%
# 8 Apple 99.76%
# 9 Apple 99.76%
# 10 Apple 99.38%
# === A frame took 1.594 seconds
# 0 Oriental melon 92.52%
# 1 Oriental melon 80.08%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.94%
# 6 Tomato 99.91%
# 7 Tomato 96.96%
# 8 Apple 99.88%
# 9 Apple 99.80%
# 10 Apple 99.62%
# === A frame took 1.627 seconds
# 0 Oriental melon 93.68%
# 1 Oriental melon 82.08%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.93%
# 6 Tomato 99.91%
# 7 Tomato 96.40%
# 8 Apple 99.89%
# 9 Apple 99.80%
# 10 Apple 99.78%
# === A frame took 1.602 seconds
# 0 Oriental melon 96.86%
# 1 Oriental melon 84.26%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.93%
# 6 Tomato 99.91%
# 7 Tomato 95.49%
# 8 Apple 99.87%
# 9 Apple 99.79%
# 10 Apple 99.71%
# === A frame took 1.585 seconds
# 0 Oriental melon 95.02%
# 1 Oriental melon 81.57%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.93%
# 6 Tomato 99.90%
# 7 Tomato 95.97%
# 8 Apple 99.87%
# 9 Apple 99.87%
# 10 Apple 99.81%
# === A frame took 1.613 seconds
# 0 Oriental melon 95.69%
# 1 Oriental melon 74.40%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.95%
# 5 Tomato 99.92%
# 6 Tomato 99.91%
# 7 Tomato 96.73%
# 8 Apple 99.89%
# 9 Apple 99.81%
# 10 Apple 99.80%
# === A frame took 1.643 seconds
# 0 Oriental melon 97.87%
# 1 Oriental melon 85.16%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.95%
# 5 Tomato 99.93%
# 6 Tomato 99.91%
# 7 Tomato 93.44%
# 8 Apple 99.89%
# 9 Apple 99.85%
# 10 Apple 99.81%
# === A frame took 1.595 seconds
# 0 Oriental melon 98.15%
# 1 Oriental melon 87.64%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.92%
# 6 Tomato 99.91%
# 7 Tomato 93.03%
# 8 Apple 99.87%
# 9 Apple 99.85%
# 10 Apple 99.79%
# === A frame took 1.576 seconds
# 0 Oriental melon 96.40%
# 1 Oriental melon 81.36%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.94%
# 6 Tomato 99.91%
# 7 Tomato 96.29%
# 8 Apple 99.87%
# 9 Apple 99.87%
# 10 Apple 99.80%
# === A frame took 1.655 seconds
# 0 Oriental melon 94.51%
# 1 Oriental melon 80.61%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.95%
# 5 Tomato 99.94%
# 6 Tomato 99.91%
# 7 Tomato 96.75%
# 8 Apple 99.87%
# 9 Apple 99.85%
# 10 Apple 99.77%
# === A frame took 1.608 seconds
# 0 Oriental melon 97.06%
# 1 Oriental melon 81.45%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.95%
# 5 Tomato 99.94%
# 6 Tomato 99.91%
# 7 Tomato 93.92%
# 8 Apple 99.86%
# 9 Apple 99.83%
# 10 Apple 99.74%
# === A frame took 1.542 seconds
# 0 Oriental melon 97.92%
# 1 Oriental melon 83.86%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.94%
# 6 Tomato 99.91%
# 7 Tomato 92.60%
# 8 Apple 99.85%
# 9 Apple 99.78%
# 10 Apple 99.74%
# === A frame took 1.593 seconds
# 0 Oriental melon 97.24%
# 1 Oriental melon 81.44%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.94%
# 6 Tomato 99.91%
# 7 Tomato 95.92%
# 8 Apple 99.85%
# 9 Apple 99.85%
# 10 Apple 99.78%
# === A frame took 1.582 seconds
# 0 Oriental melon 97.61%
# 1 Oriental melon 75.94%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.94%
# 6 Tomato 99.92%
# 7 Tomato 96.32%
# 8 Apple 99.87%
# 9 Apple 99.78%
# 10 Apple 99.77%
# === A frame took 1.550 seconds
# 0 Oriental melon 97.73%
# 1 Oriental melon 80.76%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.94%
# 6 Tomato 99.92%
# 7 Tomato 95.33%
# 8 Apple 99.86%
# 9 Apple 99.78%
# 10 Apple 99.77%
# === A frame took 1.636 seconds
# 0 Oriental melon 98.72%
# 1 Oriental melon 82.09%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.94%
# 6 Tomato 99.91%
# 7 Tomato 94.32%
# 8 Apple 99.83%
# 9 Apple 99.77%
# 10 Apple 99.76%
# === A frame took 1.600 seconds
# 0 Oriental melon 98.76%
# 1 Oriental melon 81.52%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.95%
# 5 Tomato 99.94%
# 6 Tomato 99.91%
# 7 Tomato 95.04%
# 8 Apple 99.88%
# 9 Apple 99.85%
# 10 Apple 99.76%
# === A frame took 1.626 seconds
# 0 Oriental melon 98.05%
# 1 Oriental melon 87.51%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.96%
# 5 Tomato 99.93%
# 6 Tomato 99.90%
# 7 Tomato 94.33%
# 8 Apple 99.88%
# 9 Apple 99.86%
# 10 Apple 99.80%
# === A frame took 1.621 seconds
# 0 Oriental melon 95.88%
# 1 Oriental melon 86.62%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.96%
# 5 Tomato 99.93%
# 6 Tomato 99.91%
# 7 Tomato 94.88%
# 8 Apple 99.86%
# 9 Apple 99.84%
# 10 Apple 99.81%
# === A frame took 1.627 seconds
# 0 Oriental melon 96.99%
# 1 Oriental melon 85.81%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.96%
# 5 Tomato 99.92%
# 6 Tomato 99.91%
# 7 Tomato 93.33%
# 8 Apple 99.90%
# 9 Apple 99.80%
# 10 Apple 99.79%
# === A frame took 1.587 seconds
# 0 Oriental melon 96.25%
# 1 Oriental melon 85.22%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.96%
# 5 Tomato 99.93%
# 6 Tomato 99.90%
# 7 Tomato 95.66%
# 8 Apple 99.89%
# 9 Apple 99.81%
# 10 Apple 99.79%
# === A frame took 1.595 seconds
# 0 Oriental melon 96.80%
# 1 Oriental melon 84.93%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.96%
# 5 Tomato 99.93%
# 6 Tomato 99.90%
# 7 Tomato 92.51%
# 8 Apple 99.90%
# 9 Apple 99.83%
# 10 Apple 99.77%
# === A frame took 1.586 seconds
# 0 Oriental melon 92.11%
# 1 Oriental melon 81.36%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.96%
# 5 Tomato 99.91%
# 6 Tomato 99.91%
# 7 Tomato 92.00%
# 8 Apple 99.91%
# 9 Apple 99.84%
# 10 Apple 99.81%
# === A frame took 1.600 seconds
# 0 Oriental melon 94.87%
# 1 Oriental melon 72.65%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.96%
# 5 Tomato 99.91%
# 6 Tomato 99.90%
# 7 Tomato 93.69%
# 8 Apple 99.90%
# 9 Apple 99.81%
# 10 Apple 99.79%
# === A frame took 1.597 seconds
# 0 Oriental melon 87.73%
# 1 Oriental melon 74.00%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.95%
# 5 Tomato 99.91%
# 6 Tomato 99.89%
# 7 Tomato 94.91%
# 8 Apple 99.90%
# 9 Apple 99.75%
# 10 Apple 99.52%
# === A frame took 1.574 seconds
# 0 Oriental melon 94.00%
# 1 Oriental melon 75.50%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.95%
# 5 Tomato 99.91%
# 6 Tomato 99.89%
# 7 Tomato 92.92%
# 8 Apple 99.91%
# 9 Apple 99.78%
# 10 Apple 99.45%
# === A frame took 1.597 seconds
# 0 Oriental melon 95.91%
# 1 Oriental melon 76.87%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.95%
# 5 Tomato 99.91%
# 6 Tomato 99.89%
# 7 Tomato 90.09%
# 8 Apple 99.91%
# 9 Apple 99.76%
# 10 Apple 99.21%
# === A frame took 1.612 seconds
# 0 Oriental melon 90.99%
# 1 Oriental melon 71.40%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.92%
# 6 Tomato 99.89%
# 7 Tomato 95.37%
# 8 Apple 99.91%
# 9 Apple 99.74%
# 10 Apple 99.32%
# === A frame took 1.607 seconds
# 0 Oriental melon 95.79%
# 1 Oriental melon 75.90%
# 2 Tomato 99.97%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.94%
# 6 Tomato 99.89%
# 7 Tomato 90.10%
# 8 Apple 99.93%
# 9 Apple 99.84%
# 10 Apple 99.63%
# === A frame took 1.602 seconds
# 0 Oriental melon 96.93%
# 1 Oriental melon 75.67%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.95%
# 5 Tomato 99.93%
# 6 Tomato 99.88%
# 7 Tomato 90.07%
# 8 Apple 99.92%
# 9 Apple 99.84%
# 10 Apple 99.40%
# === A frame took 1.635 seconds
# 0 Oriental melon 96.58%
# 1 Oriental melon 80.00%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.93%
# 6 Tomato 99.88%
# 7 Tomato 88.94%
# 8 Apple 99.92%
# 9 Apple 99.82%
# 10 Apple 99.59%
# === A frame took 1.610 seconds
# 0 Oriental melon 96.67%
# 1 Oriental melon 78.82%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.93%
# 6 Tomato 99.89%
# 7 Tomato 90.42%
# 8 Apple 99.91%
# 9 Apple 99.82%
# 10 Apple 99.63%
# === A frame took 1.568 seconds
# 0 Oriental melon 96.65%
# 1 Oriental melon 80.80%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.92%
# 6 Tomato 99.88%
# 7 Tomato 89.30%
# 8 Apple 99.91%
# 9 Apple 99.76%
# 10 Apple 99.58%
# === A frame took 1.637 seconds
# 0 Oriental melon 96.20%
# 1 Oriental melon 73.77%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.91%
# 6 Tomato 99.88%
# 7 Tomato 92.06%
# 8 Apple 99.91%
# 9 Apple 99.75%
# 10 Apple 99.53%
# === A frame took 1.591 seconds
# 0 Oriental melon 94.72%
# 1 Oriental melon 75.19%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.94%
# 5 Tomato 99.91%
# 6 Tomato 99.89%
# 7 Tomato 92.84%
# 8 Apple 99.91%
# 9 Apple 99.77%
# 10 Apple 99.63%
# === A frame took 1.610 seconds
# 0 Oriental melon 93.78%
# 1 Oriental melon 71.08%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.93%
# 5 Tomato 99.90%
# 6 Tomato 99.87%
# 7 Tomato 91.51%
# 8 Apple 99.92%
# 9 Apple 99.76%
# 10 Apple 99.72%
# === A frame took 1.610 seconds
# 0 Oriental melon 93.48%
# 1 Oriental melon 68.95%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.93%
# 5 Tomato 99.88%
# 6 Tomato 99.88%
# 7 Tomato 93.43%
# 8 Apple 99.92%
# 9 Apple 99.78%
# 10 Apple 99.59%
# === A frame took 1.623 seconds
# 0 Oriental melon 86.65%
# 1 Oriental melon 60.11%
# 2 Tomato 99.96%
# 3 Tomato 99.96%
# 4 Tomato 99.93%
# 5 Tomato 99.88%
# 6 Tomato 99.88%
# 7 Tomato 95.57%
# 8 Apple 99.92%
# 9 Apple 99.76%
# 10 Apple 99.58%
# === A frame took 1.576 seconds
# 0 Oriental melon 92.35%
# 1 Oriental melon 70.38%
# 2 Tomato 99.96%
# 3 Tomato 99.95%
# 4 Tomato 99.94%
# 5 Tomato 99.93%
# 6 Tomato 99.90%
# 7 Tomato 86.72%
# 8 Apple 99.92%
# 9 Apple 99.82%
# 10 Apple 99.30%
# === A frame took 1.551 seconds
# 0 Oriental melon 96.54%
# 1 Oriental melon 71.48%
# 2 Tomato 99.96%
# 3 Tomato 99.95%
# 4 Tomato 99.95%
# 5 Tomato 99.93%
# 6 Tomato 99.90%
# 7 Tomato 80.74%
# 8 Apple 99.92%
# 9 Apple 99.81%
# 10 Apple 99.54%
# === A frame took 1.638 seconds
# --(!) No captured frame -- Break!
# elapsed time 1448.180 seconds
