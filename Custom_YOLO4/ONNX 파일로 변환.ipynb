# %%
# 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##ONNX 파일로 변환

# %%
# 오픈 소스 도구 다운로드

# %cd /content
# !git clone https://github.com/Tianxiaomo/pytorch-YOLOv4.git
# %cd pytorch-YOLOv4
# Out:
# /content
# fatal: destination path 'pytorch-YOLOv4' already exists and is not an empty directory.
# /content/pytorch-YOLOv4

# %%
# 필요한 파일 복사(cfg, weights)
# !cp /content/drive/MyDrive/Custom_YOLO4/custom/custom-train-yolo4.cfg .
# !cp /content/drive/MyDrive/Custom_YOLO4/backup/custom-train-yolo4_best.weights .

# %%
# !pwd
# Out:
# /content/pytorch-YOLOv4

# %% [markdown]
# 현재 디렉토리(pytorch-YOLOv4)에 export_onnx.py 업로드

# %%
# ONNX 변환
# !python3 export_onnx.py \
  --cfg custom-train-yolo4.cfg \
  --weights custom-train-yolo4_best.weights \
  --output custom-train-yolo4_best.onnx
# Out:
# Loading config from: custom-train-yolo4.cfg
# Exporting to ONNX: custom-train-yolo4_best.onnx
# /content/pytorch-YOLOv4/tool/yolo_layer.py:227: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   bx = bxy[:, ii : ii + 1] + torch.tensor(grid_x, device=device, dtype=torch.float32) # grid_x.to(device=device, dtype=torch.float32)
# /content/pytorch-YOLOv4/tool/yolo_layer.py:229: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# ...

# %%
# !pip install onnx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 70.7 MB/s eta 0:00:00
# ...

# %%
# ONNX 유효성 확인
import onnx

onnx_model = onnx.load("custom-train-yolo4_best.onnx")
onnx.checker.check_model(onnx_model)
print("✅ 변환된 ONNX 모델이 정상입니다.")
# Out:
# ✅ 변환된 ONNX 모델이 정상입니다.

# %% [markdown]
# ##TensorRT 파일로 변환

# %%
# trtexec 설치 확인
# ONNX 파일만 Colab에서 만든 뒤,→ .onnx 파일을 본인의 Jetson 보드에서 아래 명령으로 변환

# %%
trtexec --onnx=custom-train-yolo4_final.onnx --saveEngine=custom-train-yolo4_final.trt --explicitBatch
